# %%
import numpy as np
import pandas as pd
import pickle
import string
import scipy

# %%
pay13 = pd.read_csv('/Volumes/Seagate/Galvanize/2013 Open Payments/OP_DTL_GNRL_PGYR2013_P01172018.csv', \
                    dtype={'Recipient_Zip_Code':object,'NDC_of_Associated_Covered_Drug_or_Biological1':object})
# Out:
# /Users/kunal/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,7,9,11,16,17,21,22,23,24,35,36,37,40,41,42,43,48,49,50,51,52,54,55,56,57,58,59,60,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pay13nj= pay13[pay13['Recipient_State']=='NJ']

# %%
pay13nj.to_csv('/Volumes/Seagate/Galvanize/nj_payments_2013.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-50d6d770085b> in <module>()
# ----> 1 pay13nj.to_csv('/Volumes/Seagate/Galvanize/nj_payments_2013.csv',index=False)
#
# NameError: name 'pay13nj' is not defined

# %% [markdown]
# ### <font color='forestgreen'>Grabbing Only Columns we need</font>
#
# **nj_payments_2013.csv = ALL COLUMNS**
#
# **nj_payments_2013_consl.csv = ONLY Columns for SCRIPTS**

# %% [markdown]
# ### Just looking at duplicates & stuff now

# %%
df = payments_nj_13.groupby(['company_id','company']).sum()['amount'].to_frame()
df.reset_index(inplace=True)
df.sort_values(by='amount',ascending=False).head()
df[df['company_id'].isin(df['company_id'][df['company_id'].duplicated()])].sort_values("company_id")
#WOO NO DUPLICATES ANYMORE
# Out:
# Empty DataFrame
# Columns: [company_id, company, amount]
# Index: []

# %%
df = payments_nj_full.groupby(['npi','fn','ln']).sum()['amount'].to_frame()
df.reset_index(inplace=True)
df[df['npi'].isin(df['npi'][df['npi'].duplicated()])].sort_values("npi")
#I don't mind the duplicated names because when I search I'll use the NPI data & then print out alternative names to the user as well
# Out:
#               npi               fn            ln    amount
# 116    1013014521                S       VELASCO     38.09
# 117    1013014521            SONIA       VELASCO     17.25
# 219    1023006095             MARY     WITKOWSKI    142.79
# 220    1023006095         MARYBETH     WITKOWSKI     27.16
# 317    1023315918            LADAN       ILKHANI    268.18
# 318    1023315918            LADAN  ILKHANIZADEH     14.61
# 339    1033123914           CARLOS       QUEZADA    129.75
# 340    1033123914           CARLOS  QUEZADAREYES     94.14
# 542    1043453616            SARAH       MANSSON    107.20
# 543    1043453616        SARAHJANE       MANSSON    146.96
# 577    1053330647         JONATHAN          YRAD     75.92
# 578    1053330647  JONATHANPROCESO          YRAD     45.00
# 638    1053411272             JUNG          SHEN     52.07
# 639    1053411272          JUNGSAN          SHEN     99.94
# 655    1053457986           ASHISH        KAPOOR    162.99
# ...

# %% [markdown]
# # **<font color='red'>Payments</font>**

# %%
import pandas as pd
import numpy as np
import pickle
import re

# %%
#Reading the csv that we saved, The NDCs have to be read as objects becuase otherwise the leading 0s get cut
payments_nj_full = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'name_d1':object,'name_d5':object,'ndc_d1':object,'ndc_d2':object, \
                                   'ndc_d3':object, 'ndc_d4':object,'ndc_d5':object, 'npi':object,'company_id':object, \
                                  'payment_id':object,'record_id':object})

# %% [markdown]
# ## **<font color='royalblue'>Just doing some Groupbys here</font>**

# %%
df = payments_nj_full.groupby(['npi','fn','ln','specialty','company','year']).agg({'record_id':'count','amount':'sum'})
df.reset_index(inplace=True)
df.sort_values(by='amount',ascending=False).head()
# Out:
#                npi      fn          ln  \
# 115335  1477533925  LOWELL     KABNICK
# 93570   1386639722    MARK   HARTZBAND
# 93572   1386639722    MARK   HARTZBAND
# 115336  1477533925  LOWELL     KABNICK
# 233256  1932130317   JASON  LOWENSTEIN
#
#                                                 specialty  \
# 115335                 Other Service Providers|Specialist
# 93570   Allopathic & Osteopathic Physicians|Orthopaedi...
# 93572   Allopathic & Osteopathic Physicians|Orthopaedi...
# 115336                 Other Service Providers|Specialist
# 233256  Allopathic & Osteopathic Physicians|Orthopaedi...
#
#                        company  year  record_id     amount
# 115335           ANGIODYNAMICS  2014          3  560579.24
# 93570   ZIMMER BIOMET HOLDINGS  2015         27  501090.10
# 93572           ZIMMER HOLDING  2014         66  454611.34
# 115336           ANGIODYNAMICS  2015          3  402616.56
# 233256                NUVASIVE  2014          6  393817.87

# %%
df = payments_nj_full.groupby(['npi','fn','ln','specialty','record_id','year']).agg({'amount':'sum'})
df.reset_index(inplace=True)
df.sort_values(by='amount',ascending=False).head()
# Out:
#                npi      fn         ln  \
# 431241  1477666923  SUNEET     MITTAL
# 426248  1477533925  LOWELL    KABNICK
# 426247  1477533925  LOWELL    KABNICK
# 426266  1477533925  LOWELL    KABNICK
# 735629  1801856562    JOHN  ZIMMERMAN
#
#                                                 specialty  record_id  year  \
# 431241  Allopathic & Osteopathic Physicians|Internal M...  222073094  2014
# 426248                 Other Service Providers|Specialist  144995294  2014
# 426247                 Other Service Providers|Specialist  144995288  2014
# 426266                 Other Service Providers|Specialist  254053310  2015
# 735629  Allopathic & Osteopathic Physicians|Internal M...  222096352  2014
#
#            amount
# 431241  323987.71
# 426248  307132.23
# 426247  251973.51
# 426266  232061.39
# 735629  198746.60

# %%
payments_nj_full.groupby(['company','year']).sum()['amount'].to_frame().sort_values(by='amount',ascending=False).head(10)
# Out:
#                                       amount
# company                     year
# ASTRAZENECA PHARMACEUTICALS 2014  2092803.00
# JANSSEN PHARMACEUTICALS     2015  1901962.45
# ABBVIE                      2015  1575694.16
# ZIMMER BIOMET HOLDINGS      2015  1499579.10
# ASTRAZENECA PHARMACEUTICALS 2015  1446606.81
# JANSSEN PHARMACEUTICALS     2014  1308985.26
# ABBVIE                      2014  1282778.42
# ER SQUIBB SONS              2015   956901.59
# TEVA PHARMACEUTICALS USA    2014   953858.99
#                             2015   893263.29

# %%
print("2013 Total Payments in NJ: {}, \n Total Amount paid: {}".format(payments_nj_full.groupby(['year']).count()['amount'].to_frame()['amount'][2013],payments_nj_full.groupby(['year']).sum()['amount'].to_frame()['amount'][2013]))
print("2014 Total Payments in NJ: {}, \n Total Amount paid: {}".format(payments_nj_full.groupby(['year']).count()['amount'].to_frame()['amount'][2014],payments_nj_full.groupby(['year']).sum()['amount'].to_frame()['amount'][2014]))
print("2015 Total Payments in NJ: {}, \n Total Amount paid: {}".format(payments_nj_full.groupby(['year']).count()['amount'].to_frame()['amount'][2015],payments_nj_full.groupby(['year']).sum()['amount'].to_frame()['amount'][2015]))
# Out:
# 2013 Total Payments in NJ: 136916,
#  Total Amount paid: 13592322.070001055
# 2014 Total Payments in NJ: 390602,
#  Total Amount paid: 36071036.550007306
# 2015 Total Payments in NJ: 399498,
#  Total Amount paid: 38499500.149998784

# %%
print("2013 Avg amount paid: {}".format(payments_nj_full.groupby(['year']).agg({'amount':'mean'})['amount'][2013]))
print("2014 Avg amount paid: {}".format(payments_nj_full.groupby(['year']).agg({'amount':'mean'})['amount'][2014]))
print("2015 Avg amount paid: {}".format(payments_nj_full.groupby(['year']).agg({'amount':'mean'})['amount'][2015]))
# Out:
# 2013 Avg amount paid: 99.27489898916895
# 2014 Avg amount paid: 92.3472909765114
# 2015 Avg amount paid: 96.36969434139542

# %%
payments_nj_full.isnull().sum()
# Out:
# payment_id         0
# fn                 0
# ln                 0
# address            0
# city               0
# state              0
# zip                0
# specialty       1297
# company_id         0
# company            0
# amount             0
# form               0
# nature             0
# phys_owns          0
# record_id          0
# name_d1            0
# name_d2          150
# name_d3            0
# name_d4            0
# name_d5            0
# ndc_d1        267703
# ndc_d2        753287
# ndc_d3        873882
# ndc_d4        919049
# ndc_d5        924024
# year               0
# npi                0
# dtype: int64

# %%
payments_nj_full.replace(to_replace='NAN',value=np.nan,inplace=True)

# %% [markdown]
# ## **<font color='royalblue'>Looking at the typical amount paid</font>**

# %%
pd.concat([pd.DataFrame(np.array(['2013','|','|','2013','2013','|','|','2013']), \
             index=list(payments_nj_full[payments_nj_full['year']==2013].describe().index)), \
           payments_nj_full[payments_nj_full['year']==2013].describe(). \
           drop(['year'],axis=1), \
           pd.DataFrame(np.array(['2014','|','|','2014','2014','|','|','2014']), \
             index=list(payments_nj_full[payments_nj_full['year']==2014].describe().index)), \
           payments_nj_full[payments_nj_full['year']==2014].describe(). \
           drop(['year'],axis=1), \
           pd.DataFrame(np.array(['2015','|','|','2015','2015','|','|','2015']), \
             index=list(payments_nj_full[payments_nj_full['year']==2015].describe().index)), \
           payments_nj_full[payments_nj_full['year']==2015].describe(). \
           drop(['year'],axis=1)],axis=1)
# Out:
#           0         amount     0         amount     0         amount
# count  2013  136916.000000  2014  390602.000000  2015  399498.000000
# mean      |      99.274899     |      92.347291     |      96.369694
# std       |     662.003935     |    1105.938114     |     944.139931
# min    2013       0.000000  2014       0.000000  2015       0.010000
# 25%    2013      11.840000  2014      11.090000  2015      11.610000
# 50%       |      16.050000     |      15.260000     |      15.710000
# 75%       |      23.990000     |      21.810000     |      21.940000
# max    2013  123255.000000  2014  323987.710000  2015  232061.390000

# %%
d = payments_nj_full.describe(include='all').drop(['state','year'],axis=1).to_dict('dict')
nd = {}
for col in d:
    nd[col]={}
    for val in d[col]:
        try:
            x = np.isnan(d[col][val])
            if x:
                continue
            elif not x:
                nd[col][val] = d[col][val]
        except:
            nd[col][val] = d[col][val]
nd
# Out:
# {'address': {'count': 927016,
#   'freq': 5782,
#   'top': '100 MADISON AVE',
#   'unique': 24187},
#  'amount': {'25%': 11.43,
#   '50%': 15.57,
#   '75%': 22.15,
#   'count': 927016.0,
#   'max': 323987.71,
#   'mean': 95.10392352450893,
#   'min': 0.0,
#   'std': 981.9568902637541},
#  'city': {'count': 927016, 'freq': 22669, 'top': 'TOMSRIVER', 'unique': 1274},
#  'company': {'count': 927016,
#   'freq': 63142,
#   'top': 'ASTRAZENECA PHARMACEUTICALS',
#   'unique': 874},
#  'company_id': {'count': 927016,
#   'freq': 63142,
#   'top': '100000000146',
#   'unique': 867},
#  'fn': {'count': 927016, 'freq': 30188, 'top': 'MICHAEL', 'unique': 4504},
#  'form': {'count': 927016,
#   'freq': 779838,
#   'top': 'In-kind items and services',
#   'unique': 3},
#  'ln': {'count': 927016, 'freq': 14100, 'top': 'PATEL', 'unique': 10882},
#  'name_d1': {'count': 771821, 'freq': 25231, 'top': 'XARELTO', 'unique': 1336},
# ...

# %% [markdown]
# # **<font color='red'>Scripts</font>**

# %%
scriptsnj13 = pd.read_csv('/Volumes/Seagate/Galvanize/2013_scriptsnj.csv', dtype={'npi':object})
scriptsnj14 = pd.read_csv('/Volumes/Seagate/Galvanize/2014_scriptsnj.csv', dtype={'npi':object})
scriptsnj15 = pd.read_csv('/Volumes/Seagate/Galvanize/2015_scriptsnj.csv', dtype={'npi':object})

# %%
scriptsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv', dtype={'npi':object})

# %%
scriptsnjfull.head(2)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1528036670                      LANTERI                   VINCENT
# 1  1528036670                      LANTERI                   VINCENT
#
#   nppes_provider_city nppes_provider_state specialty_description  year  \
# 0             MAYWOOD                   NJ               Urology  2013
# 1             MAYWOOD                   NJ               Urology  2013
#
#                     drug_name                generic_name  total_claim_count  \
# 0                      VIAGRA                  SILDENAFIL                 48
# 1  CLOTRIMAZOLE BETAMETHASONE  CLOTRIMAZOLE BETAMETHASONE                 16
#
#    total_day_supply  total_drug_cost  brand_drug?
# 0              1481          8957.33         True
# 1               367           806.59        False

# %%
scriptsnjfull.groupby(['year','brand_drug?']).agg({'total_claim_count':'sum','total_drug_cost':'sum'})
# Out:
#                   total_claim_count  total_drug_cost
# year brand_drug?
# 2013 False                 22082933     6.346964e+08
#      True                   6208380     1.955857e+09
# 2014 False                 23288383     6.772004e+08
#      True                   5684384     2.276462e+09
# 2015 False                 24716615     6.878899e+08
#      True                   5196218     2.533153e+09

# %%
x = scriptsnjfull.groupby(['year','brand_drug?']).agg({'total_claim_count':'sum','total_drug_cost':'sum'})
x['avg_drug_cost'] = (x['total_drug_cost']/x['total_claim_count'])
x
# Out:
#                   total_claim_count  total_drug_cost  avg_drug_cost
# year brand_drug?
# 2013 False                 22082933     6.346964e+08      28.741488
#      True                   6208380     1.955857e+09     315.035007
# 2014 False                 23288383     6.772004e+08      29.078891
#      True                   5684384     2.276462e+09     400.476500
# 2015 False                 24716615     6.878899e+08      27.831074
#      True                   5196218     2.533153e+09     487.499366

# %%
s = scriptsnjfull.groupby(['specialty_description','brand_drug?']).agg({'total_claim_count':'sum'}).reset_index()
s.head()
# Out:
#   specialty_description  brand_drug?  total_claim_count
# 0         Acupuncturist        False                 35
# 1    Addiction Medicine        False               3294
# 2    Addiction Medicine         True                224
# 3    Allergy/Immunology        False             111802
# 4    Allergy/Immunology         True              72457

# %%
#Checking which specialities write MORE brand name prescriptions than generics
d = {}
for i in s['specialty_description'].unique():
    d[i] = {}
    for tf in s['brand_drug?'].unique():
        n = list((s[(s['specialty_description']==i) & (s['brand_drug?']==tf)])['total_claim_count'])
        for j in n:
            d[i][tf] = j
for i in d:
     v=list(d[i].values())
     k=list(d[i].keys())
     d[i] = k[v.index(max(v))]
[k for k,v in d.items() if v == True]
# Out:
# ['Optometry', 'Personal Emergency Response Attendant', 'Radiation Oncology']

# %%
s[s['specialty_description'].isin(['Optometry', 'Personal Emergency Response Attendant', 'Radiation Oncology'])]
# Out:
#                      specialty_description  brand_drug?  total_claim_count
# 128                              Optometry        False             138243
# 129                              Optometry         True             170255
# 148  Personal Emergency Response Attendant        False                 28
# 149  Personal Emergency Response Attendant         True                 36
# 178                     Radiation Oncology        False              13864
# 179                     Radiation Oncology         True              38130

# %% [markdown]
# # **<font color='red'>Payments + Scripts</font>**

# %%
import numpy as np
import pandas as pd
import pickle

# %%
scriptsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv',dtype={'npi':object})

# %%
#Reading the csv that we saved, The NDCs have to be read as objects becuase otherwise the leading 0s get cut
paymentsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'name_d1':object,'name_d5':object,'ndc_d1':object,'ndc_d2':object, \
                                   'ndc_d3':object, 'ndc_d4':object,'ndc_d5':object, 'npi':object,'company_id':object, \
                                  'payment_id':object,'record_id':object})

# %%
paymentsnjfull.head(1)
# Out:
#   payment_id         npi      fn      ln                address        city  \
# 0   235088.0  1174629083  FATIMA  ASGHAR  94 OLD SHORT HILLS RD  LIVINGSTON
#
#   state    zip                                          specialty  \
# 0    NJ  07039  Allopathic & Osteopathic Physicians|Internal M...
#
#      company_id  ...  name_d2  name_d3 name_d4 name_d5      ndc_d1 ndc_d2  \
# 0  100000005529  ...      NaN      NaN     NaN     NaN  0456120130    NaN
#
#   ndc_d3 ndc_d4 ndc_d5  year
# 0    NaN    NaN    NaN  2013
#
# [1 rows x 27 columns]

# %% [markdown]
# # <font color=#00FFCD>**HYPOTHESIS TESTING**</font>

# %%
p13 = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_2013_consl.csv',
                            dtype={'zip':object,'name_d1':object,'name_d5':object,'ndc_d1':object,'ndc_d2':object, \
                                   'ndc_d3':object, 'ndc_d4':object,'ndc_d5':object, 'npi':object,'company_id':object, \
                                  'payment_id':object,'record_id':object})

# %%
scriptsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv',dtype={'npi':object})

# %%
scriptsnjfull.head(2)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1528036670                      LANTERI                   VINCENT
# 1  1528036670                      LANTERI                   VINCENT
#
#   nppes_provider_city nppes_provider_state specialty_description  year  \
# 0             MAYWOOD                   NJ               Urology  2013
# 1             MAYWOOD                   NJ               Urology  2013
#
#    recieved_payments  total_claim_count  amount_brand  \
# 0               True                 48            48
# 1               True                 16             0
#
#                     drug_name                generic_name  brand_drug?  \
# 0                      VIAGRA                  SILDENAFIL         True
# 1  CLOTRIMAZOLE BETAMETHASONE  CLOTRIMAZOLE BETAMETHASONE        False
#
#    total_day_supply  total_drug_cost
# 0              1481          8957.33
# 1               367           806.59

# %%
p13.head(2)
# Out:
#   payment_id         fn      ln                address          city state  \
# 0   235088.0     FATIMA  ASGHAR  94 OLD SHORT HILLS RD    LIVINGSTON    NJ
# 1   334868.0  RAGHUVEER   ANNAM      290 RED SCHOOL LN  PHILLIPSBURG    NJ
#
#      zip                                          specialty    company_id  \
# 0  07039  Allopathic & Osteopathic Physicians|Internal M...  100000005529
# 1  08865  Allopathic & Osteopathic Physicians|Internal M...  100000005529
#
#                   company     ...      name_d3 name_d4 name_d5      ndc_d1  \
# 0  FOREST PHARMACEUTICALS     ...          NAN     NAN     NAN  0456120130
# 1  FOREST PHARMACEUTICALS     ...          NAN     NAN     NAN  0456120130
#
#   ndc_d2 ndc_d3 ndc_d4 ndc_d5  year         npi
# 0    NaN    NaN    NaN    NaN  2013  1174629083
# 1    NaN    NaN    NaN    NaN  2013  1386735850
#
# [2 rows x 27 columns]

# %%
s13 = pd.read_csv('/Volumes/Seagate/Galvanize/2013_scriptsnj.csv', dtype={'npi':object})

# %%
print("{} unique NPIs who got paid \n{} unique NPIs who wrote prescriptions \n{} unique NPIs who wrote prescriptions & got a payment". \
      format(len(p13.npi.unique()), len(s13.npi.unique()),len(list(set(p13.npi).intersection(set(s13.npi))))))
# Out:
# 12034 unique NPIs who got paid
# 22485 unique NPIs who wrote prescriptions
# 11267 unique NPIs who wrote prescriptions & got a payment

# %%
#Groupby to see the amount of doctors from that speciality who did & did not recieve payments
grp = s13.groupby(['specialty_description','recieved_payments'])['npi'].nunique().to_frame().reset_index()
#I'm only going to look at the specialities where the number of doctors for this is above 30
grp30 = grp[grp['npi']>=30]
#Groupby function to only find the specialities who have > 30 docs both recieving & not recieving payments
both = grp30.groupby(['specialty_description'])['recieved_payments'].count().to_frame().reset_index()
blist = list(both[both['recieved_payments']==2]['specialty_description'])

# %%
0.05/len(blist)/2
# Out:
# 0.0008064516129032258

# %%
"""Using a for loop to go thorugh all the specialites that have more than 30 people reicieving & not recieiving
payments to see if there's a significant difference in the means between them
"""
for spec in blist:
    df = s13[s13['specialty_description']==spec].groupby(['npi','recieved_payments']).agg({'amount_brand':'sum','total_claim_count':'sum'})
    df['%_brand'] = (df['amount_brand']/df['total_claim_count'])
    df = df.reset_index()
    paid = df[df['recieved_payments']==True]
    np = df[df['recieved_payments']==False]
    #Making sure I have more than 1 sample
    if (len(np)-1 > 0) & (len(paid)-1 > 0) :
        x, y = (ttest_ind(paid['%_brand'], np['%_brand'], equal_var = False))
        """
        This is a 2 tailed t-test so we'll be looking at 1/2 of our p-value, also since we are running
        so many t-tests the probability of me encountering a Type I eroor increases greatly so I'm also going to use
        a Bonferroni correction (new_sig_level = sig_level(0.05)/# tests)
        """
        if y <= (0.05/len(blist)/2) or y >= (1-(0.05/len(blist)/2)):
            print("{}: t-stat={}, pvalue={}".format(spec,x,y))
            print("         {} paid, {} not paid".format(len(paid),len(np)))
# Out:
# Dermatology: t-stat=3.501925811988889, pvalue=0.0005242821301110622
#          262 paid, 101 not paid
# Family Practice: t-stat=7.25842716397448, pvalue=7.061001172886413e-13
#          927 paid, 719 not paid
# Internal Medicine: t-stat=8.566627068969058, pvalue=1.9861614323018996e-17
#          2034 paid, 1351 not paid
# Neurology: t-stat=3.863386913506997, pvalue=0.00016712012461033476
#          286 paid, 98 not paid
# Obstetrics/Gynecology: t-stat=4.645070362039651, pvalue=4.6920241438591465e-06
#          582 paid, 247 not paid
# Ophthalmology: t-stat=6.277403601100644, pvalue=1.1175381702472372e-09
#          375 paid, 187 not paid

# %%
#Looking at dentists becuase of my background
den = s13[s13['specialty_description']=='Dentist'].groupby(['recieved_payments']).agg({"npi": lambda x: x.nunique(),'amount_brand':'sum','total_claim_count':'sum'})
den['%_brand'] = (den['amount_brand']/den['total_claim_count'])
den
# Out:
#                     npi  amount_brand  total_claim_count   %_brand
# recieved_payments
# False              2192          1383             100639  0.013742
# True                746           703              43587  0.016129

# %%
dentists = s13[s13['specialty_description']=='Dentist'].groupby(['npi','recieved_payments']).agg({'amount_brand':'sum','total_claim_count':'sum'})
dentists['%_brand'] = (dentists['amount_brand']/dentists['total_claim_count'])
dentists.reset_index(inplace=True)
dentists.head(2)
# Out:
#           npi  recieved_payments  amount_brand  total_claim_count  %_brand
# 0  1003019910              False             0                229      0.0
# 1  1003025503              False             0                 16      0.0

# %%
from scipy.stats import ttest_ind

# %% [markdown]
# ## **<font color='purple'>Dentists = Not a significant diff</font>**

# %%
dpaid = dentists[dentists['recieved_payments']==True]
dnp = dentists[dentists['recieved_payments']==False]
print(len(dpaid),len(dnp))
print(ttest_ind(dpaid['%_brand'], dnp['%_brand'], equal_var = False))
# Out:
# 746 2192
# Ttest_indResult(statistic=0.3113186108872277, pvalue=0.7556123258752613)

# %%
im = s13[s13['specialty_description']=='Internal Medicine'].groupby(['recieved_payments']).agg({"npi": lambda x: x.nunique(),'amount_brand':'sum','total_claim_count':'sum'})
im['%_brand'] = (im['amount_brand']/im['total_claim_count'])
im
# Out:
#                     npi  amount_brand  total_claim_count   %_brand
# recieved_payments
# False              1351        468803            2618932  0.179005
# True               2034       1958161            9109833  0.214950

# %%
internal = s13[s13['specialty_description']=='Internal Medicine'].groupby(['npi','recieved_payments']).agg({'amount_brand':'sum','total_claim_count':'sum'})
internal['%_brand'] = (internal['amount_brand']/internal['total_claim_count'])
internal.reset_index(inplace=True)
internal.head(2)
# Out:
#           npi  recieved_payments  amount_brand  total_claim_count   %_brand
# 0  1003020975              False           156               1205  0.129461
# 1  1003041062              False            12                174  0.068966

# %% [markdown]
# ## **<font color='blue'>Internal Medicine = Significant Difference </font>**
# Large T score = Significantly different
#
# Very small p-value, can reject null hypothesis

# %%
impaid = internal[internal['recieved_payments']==True]
imnp = internal[internal['recieved_payments']==False]
print(len(impaid),len(imnp))
#Checking if im-paid mean of % brand subscribed > im-not_paid
print(ttest_ind(impaid['%_brand'], imnp['%_brand'], equal_var = False))
# Out:
# 2034 1351
# Ttest_indResult(statistic=8.566627068969058, pvalue=1.9861614323018996e-17)

# %%
cs = s13[s13['specialty_description']=='Cardiac Surgery'].groupby(['recieved_payments']).agg({"npi": lambda x: x.nunique(),'amount_brand':'sum','total_claim_count':'sum'})
cs['%_brand'] = (cs['amount_brand']/cs['total_claim_count'])
cs
# Out:
#                    npi  amount_brand  total_claim_count   %_brand
# recieved_payments
# False                2             0                 24  0.000000
# True                14          1309               9023  0.145074

# %%
card = s13[s13['specialty_description']=='Cardiac Surgery'].groupby(['npi','recieved_payments']).agg({'amount_brand':'sum','total_claim_count':'sum'})
card['%_brand'] = (card['amount_brand']/card['total_claim_count'])
card.reset_index(inplace=True)
card.head(2)
# Out:
#           npi  recieved_payments  amount_brand  total_claim_count  %_brand
# 0  1013918416               True             0                 27      0.0
# 1  1023216660              False             0                 13      0.0

# %% [markdown]
# ## **<font color='blue'>Cardiac Surgery = Significant Difference </font>**
# Large T score = Significantly different
#
# Very small p-value, can reject null hypothesis

# %%
cpaid = card[card['recieved_payments']==True]
cnp = card[card['recieved_payments']==False]
print(len(cpaid),len(cnp))
#Checking if im-paid mean of % brand subscribed > im-not_paid
print(ttest_ind(cpaid['%_brand'], cnp['%_brand'], equal_var = False))
# Out:
# 2034 1351
# Ttest_indResult(statistic=8.566627068969058, pvalue=1.9861614323018996e-17)

# %% [markdown]
# Interesting, for Diagnostic Radiology I got a negative statistic meaning doctors in this specialty are
# LESS likey to prescribe brand name drugs if they are paid

# %%
scriptsnj13.groupby('recieved_payments')['npi'].nunique()
# Out:
# recieved_payments
# False    11218
# True     11267
# Name: npi, dtype: int64

# %%
scriptsnj14.groupby('recieved_payments')['npi'].nunique()
# Out:
# recieved_payments
# False     9727
# True     13539
# Name: npi, dtype: int64

# %%
scriptsnj15.groupby('recieved_payments')['npi'].nunique()
# Out:
# recieved_payments
# False    10192
# True     13721
# Name: npi, dtype: int64

# %%
script = s13.groupby(['npi','nppes_provider_first_name','nppes_provider_last_org_name','recieved_payments','specialty_description'],as_index=False).agg({'total_claim_count':'sum','amount_brand':'sum'})
script['%_brand'] = (script['amount_brand']/script['total_claim_count'])

# %%
pay = p13.groupby('npi',as_index=False).agg({'payment_id':'count','amount':'sum'})

# %%
w = script.merge(pay,on='npi',how='left')

# %%
w.head(2)
# Out:
#           npi nppes_provider_first_name nppes_provider_last_org_name  \
# 0  1003002072                 ALEXANDER                     GOTESMAN
# 1  1003002858                       AMY                       GIBSON
#
#    recieved_payments specialty_description  total_claim_count  amount_brand  \
# 0               True               Urology                237           123
# 1              False    Nurse Practitioner               1793           327
#
#     %_brand  payment_id  amount
# 0  0.518987         2.0   28.23
# 1  0.182376         NaN     NaN

# %%
w.rename({'nppes_provider_first_name':'fn','nppes_provider_last_org_name':'ln','payment_id':'num_payments','specialty_description':'specialty'},axis='columns',inplace=True)

# %%
w.fillna(0,inplace=True)

# %%
w.head(2)
# Out:
#           npi         fn        ln  recieved_payments           specialty  \
# 0  1003002072  ALEXANDER  GOTESMAN               True             Urology
# 1  1003002858        AMY    GIBSON              False  Nurse Practitioner
#
#    total_claim_count  amount_brand   %_brand  num_payments  amount
# 0                237           123  0.518987           2.0   28.23
# 1               1793           327  0.182376           0.0    0.00

# %%
w = w[w['recieved_payments']==True]

# %%
w.to_csv('/Users/kunal/Downloads/pay_script_13.csv',index=False)

# %%
scriptsnjfull.head(2)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1528036670                      LANTERI                   VINCENT
# 1  1528036670                      LANTERI                   VINCENT
#
#   nppes_provider_city nppes_provider_state specialty_description  year  \
# 0             MAYWOOD                   NJ               Urology  2013
# 1             MAYWOOD                   NJ               Urology  2013
#
#    recieved_payments  total_claim_count  amount_brand  \
# 0               True                 48            48
# 1               True                 16             0
#
#                     drug_name                generic_name  brand_drug?  \
# 0                      VIAGRA                  SILDENAFIL         True
# 1  CLOTRIMAZOLE BETAMETHASONE  CLOTRIMAZOLE BETAMETHASONE        False
#
#    total_day_supply  total_drug_cost
# 0              1481          8957.33
# 1               367           806.59

# %%
paymentsnjfull.head(2)
# Out:
#   payment_id         npi         fn      ln                address  \
# 0   235088.0  1174629083     FATIMA  ASGHAR  94 OLD SHORT HILLS RD
# 1   334868.0  1386735850  RAGHUVEER   ANNAM      290 RED SCHOOL LN
#
#            city state    zip  \
# 0    LIVINGSTON    NJ  07039
# 1  PHILLIPSBURG    NJ  08865
#
#                                            specialty    company_id  ...   \
# 0  Allopathic & Osteopathic Physicians|Internal M...  100000005529  ...
# 1  Allopathic & Osteopathic Physicians|Internal M...  100000005529  ...
#
#   name_d2  name_d3 name_d4 name_d5      ndc_d1 ndc_d2 ndc_d3 ndc_d4 ndc_d5  \
# 0     NaN      NaN     NaN     NaN  0456120130    NaN    NaN    NaN    NaN
# 1     NaN      NaN     NaN     NaN  0456120130    NaN    NaN    NaN    NaN
#
#    year
# 0  2013
# 1  2013
#
# [2 rows x 27 columns]

# %%
script = scriptsnjfull.groupby(['year','npi','nppes_provider_first_name','nppes_provider_last_org_name','recieved_payments','specialty_description'],as_index=False).agg({'total_claim_count':'sum','amount_brand':'sum'})
script['%_brand'] = (script['amount_brand']/script['total_claim_count'])

# %%
pay = paymentsnjfull.groupby(['year','npi'],as_index=False).agg({'payment_id':'count','amount':'sum'})

# %%
pay_script = script.merge(pay,on=['year','npi'],how='left')

# %%
pay_script.rename({'nppes_provider_first_name':'fn','nppes_provider_last_org_name':'ln','payment_id':'num_payments','specialty_description':'specialty'},axis='columns',inplace=True)
pay_script.fillna(0,inplace=True)

# %%
pay_script['amount_generic'] = (pay_script['total_claim_count']-pay_script['amount_brand'])

# %%
pay_script.to_csv('/Users/kunal/Downloads/pay_script_full.csv',index=False)

# %%
pay_script_t = pay_script[pay_script['recieved_payments']==True]

# %%
pay_script_t.to_csv('/Users/kunal/Downloads/pay_script_full_onlypaid.csv',index=False)

# %%
pay_script_t.head()
# Out:
#     year         npi         fn             ln  recieved_payments  \
# 0   2013  1003002072  ALEXANDER       GOTESMAN               True
# 8   2013  1003029836     THOMAS        MUELLER               True
# 10  2013  1003034034      SUSAN         GORDON               True
# 14  2013  1003046889   VASILIKI  PAPATHANASIOU               True
# 17  2013  1003054552   CATHLEEN          SAROS               True
#
#           specialty  total_claim_count  amount_brand   %_brand  num_payments  \
# 0           Urology                237           123  0.518987           2.0
# 8           Urology                832           242  0.290865          26.0
# 10    Ophthalmology               1033           413  0.399806           5.0
# 14  Family Practice                263             0  0.000000           3.0
# 17  Family Practice                513            25  0.048733           5.0
#
#      amount  amount_generic
# 0     28.23             114
# 8   2451.22             590
# ...

# %%
import pandas as pd
import numpy as np
paid = pd.read_csv('/Users/kunal/Downloads/pay_script_full_onlypaid.csv',dtype={'npi':object})

# %%
paid.head(2)
# Out:
#    year         npi         fn        ln  recieved_payments specialty  \
# 0  2013  1003002072  ALEXANDER  GOTESMAN               True   Urology
# 1  2013  1003029836     THOMAS   MUELLER               True   Urology
#
#    total_claim_count  amount_brand   %_brand  num_payments   amount  \
# 0                237           123  0.518987           2.0    28.23
# 1                832           242  0.290865          26.0  2451.22
#
#    amount_generic
# 0             114
# 1             590

# %%
x = paid.groupby('npi')['year'].nunique().to_frame().reset_index().sort_values('year',ascending=False)
x3 = x[x['year']==3]

# %%
x3.sort_values(by='npi')
# Out:
#        year         npi         fn         ln  recieved_payments  \
# 0      2013  1003002072  ALEXANDER   GOTESMAN               True
# 11267  2014  1003002072  ALEXANDER   GOTESMAN               True
# 24806  2015  1003002072  ALEXANDER   GOTESMAN               True
# 4616   2013  1417915968   THADDEUS     AVERSA               True
# 16824  2014  1417915968   THADDEUS     AVERSA               True
# 30422  2015  1417915968   THADDEUS     AVERSA               True
# 4617   2013  1417916131      DAVID    STEWART               True
# 16825  2014  1417916131      DAVID    STEWART               True
# 30423  2015  1417916131      DAVID    STEWART               True
# 4619   2013  1417919051      SAIDA       BAXT               True
# 16831  2014  1417919051      SAIDA       BAXT               True
# 30429  2015  1417919051      SAIDA       BAXT               True
# 8650   2013  1770553042      STEVE  COZAMANIS               True
# ...

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'npi':object,'company_id':object}, \
                  usecols=[1,2,3,10,11,12,13,26])

# %%
paid[paid['npi']=='1386735850'].groupby('year')['amount'].sum()
# Out:
# year
# 2013    661.89
# 2014     77.82
# 2015     41.95
# Name: amount, dtype: float64

# %%
#Reading the csv that we saved, The NDCs have to be read as objects becuase otherwise the leading 0s get cut
paymentsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'name_d1':object,'name_d5':object,'ndc_d1':object,'ndc_d2':object, \
                                   'ndc_d3':object, 'ndc_d4':object,'ndc_d5':object, 'npi':object,'company_id':object, \
                                  'payment_id':object,'record_id':object})

# %%
paymentsnjfull.head(2)
# Out:
#   payment_id         npi         fn      ln                address  \
# 0   235088.0  1174629083     FATIMA  ASGHAR  94 OLD SHORT HILLS RD
# 1   334868.0  1386735850  RAGHUVEER   ANNAM      290 RED SCHOOL LN
#
#            city state    zip  \
# 0    LIVINGSTON    NJ  07039
# 1  PHILLIPSBURG    NJ  08865
#
#                                            specialty    company_id  ...   \
# 0  Allopathic & Osteopathic Physicians|Internal M...  100000005529  ...
# 1  Allopathic & Osteopathic Physicians|Internal M...  100000005529  ...
#
#   name_d2  name_d3 name_d4 name_d5      ndc_d1 ndc_d2 ndc_d3 ndc_d4 ndc_d5  \
# 0     NaN      NaN     NaN     NaN  0456120130    NaN    NaN    NaN    NaN
# 1     NaN      NaN     NaN     NaN  0456120130    NaN    NaN    NaN    NaN
#
#    year
# 0  2013
# 1  2013
#
# [2 rows x 27 columns]

# %%
paymentsnjfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927016 entries, 0 to 927015
# Data columns (total 27 columns):
# payment_id    927016 non-null object
# npi           927016 non-null object
# fn            927016 non-null object
# ln            927016 non-null object
# address       927016 non-null object
# city          927016 non-null object
# state         927016 non-null object
# zip           927016 non-null object
# specialty     925719 non-null object
# company_id    927016 non-null object
# company       927016 non-null object
# amount        927016 non-null float64
# form          927016 non-null object
# nature        927016 non-null object
# phys_owns     927016 non-null object
# record_id     927016 non-null object
# name_d1       771821 non-null object
# name_d2       199702 non-null object
# name_d3       59622 non-null object
# name_d4       9082 non-null object
# name_d5       3035 non-null object
# ndc_d1        659313 non-null object
# ...

# %%
p = paymentsnjfull[['npi','fn','ln','company','amount','year']]

# %%
p.head()
# Out:
#           npi         fn         ln                 company  amount  year
# 0  1174629083     FATIMA     ASGHAR  FOREST PHARMACEUTICALS   14.83  2013
# 1  1386735850  RAGHUVEER      ANNAM  FOREST PHARMACEUTICALS   72.90  2013
# 2  1659372829     DEEPAK       AMIN  FOREST PHARMACEUTICALS    1.39  2013
# 3  1659372829     DEEPAK       AMIN  FOREST PHARMACEUTICALS    1.40  2013
# 4  1912047754     AURORA  ANDREESCU  FOREST PHARMACEUTICALS   13.38  2013

# %%
x = p.groupby(['npi','fn','ln','year','company']).agg({'amount':'sum'}).reset_index()

# %%
xname = x[x['npi']=='1922188184']
#This guy has a shit ton of payments so just to test out graphing

# %%
xname.head(2)
# Out:
#                npi       fn       ln  year        company  amount
# 231035  1922188184  JEFFREY  FARNESE  2013         ABBVIE  135.25
# 231036  1922188184  JEFFREY  FARNESE  2013  AMARIN PHARMA   30.82

# %%
tb = pd.pivot_table(xname, index=['year'],columns='company',values=['amount']).reset_index()
tb.fillna(value=0,inplace=True)
tb.columns = tb.columns.droplevel()
tb.columns = ['year']+list(tb.columns)[1:]

# %%
tb
# Out:
#    year   ABBVIE  ACTAVIS PHARMA  AMARIN PHARMA  ARBOR PHARMACEUTICALS  \
# 0  2013   98.030          17.220         30.820                   0.00
# 1  2014  313.320          39.910         42.375                  39.62
# 2  2015  199.235          76.095         17.200                  62.12
#
#    ASTELLAS PHARMA US  ASTRAZENECA PHARMACEUTICALS  AUXILIUM PHARMACEUTICALS  \
# 0               10.24                       37.970                     98.55
# 1               23.31                      492.600                     60.31
# 2               22.83                      435.075                      0.00
#
#    AVANIR PHARMACEUTICALS  BOEHRINGER INGELHEIM PHARMACEUTICALS  \
# 0                   22.48                                36.335
# 1                  293.38                                42.285
# 2                  106.44                               120.005
#
#         ...          PFIZER  PURDUE PHARMA  SANOFIAVENTIS US  \
# ...

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'npi':object,'company_id':object}, \
                  usecols=[1,2,3,4,5,6,7,8,10,11,12,13,26])

# %%
#Just replace the npi here for the doctor you're searching for
x = paid[paid['npi']=='1922188184'].groupby(['npi','fn','ln','year','company']).agg({'amount':'sum'}).reset_index()
tb = pd.pivot_table(x, index=['year'],columns='company',values=['amount']).reset_index()
tb.columns = tb.columns.droplevel()
tb.columns = ['year']+list(tb.columns)[1:]

# %%
x = tb[tb.columns[0]].to_frame()
x.drop('year',axis=1,inplace=True)

# %%
for i in range(len(tb.columns)):
    x[tb.columns[i]] = tb[tb.columns[i]]

# %%
x.head()
# Out:
#    year   ABBVIE  ACTAVIS PHARMA  AMARIN PHARMA  ARBOR PHARMACEUTICALS  \
# 0  2013   98.030          17.220         30.820                    NaN
# 1  2014  313.320          39.910         42.375                  39.62
# 2  2015  199.235          76.095         17.200                  62.12
#
#    ASTELLAS PHARMA US  ASTRAZENECA PHARMACEUTICALS  AUXILIUM PHARMACEUTICALS  \
# 0               10.24                       37.970                     98.55
# 1               23.31                      492.600                     60.31
# 2               22.83                      435.075                       NaN
#
#    AVANIR PHARMACEUTICALS  BOEHRINGER INGELHEIM PHARMACEUTICALS  \
# 0                   22.48                                36.335
# 1                  293.38                                42.285
# 2                  106.44                               120.005
#
#         ...          PFIZER  PURDUE PHARMA  SANOFIAVENTIS US  \
# ...

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'name_d1':object,'name_d5':object,'ndc_d1':object,'ndc_d2':object, \
                                   'ndc_d3':object, 'ndc_d4':object,'ndc_d5':object, 'npi':object,'company_id':object, \
                                  'payment_id':object,'record_id':object})

# %%
paid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927016 entries, 0 to 927015
# Data columns (total 27 columns):
# payment_id    927016 non-null object
# npi           927016 non-null object
# fn            927016 non-null object
# ln            927016 non-null object
# address       927016 non-null object
# city          927016 non-null object
# state         927016 non-null object
# zip           927016 non-null object
# specialty     925719 non-null object
# company_id    927016 non-null object
# company       927016 non-null object
# amount        927016 non-null float64
# form          927016 non-null object
# nature        927016 non-null object
# phys_owns     927016 non-null object
# record_id     927016 non-null object
# name_d1       771821 non-null object
# name_d2       199702 non-null object
# name_d3       59622 non-null object
# name_d4       9082 non-null object
# name_d5       3035 non-null object
# ndc_d1        659313 non-null object
# ...

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'zip':object,'npi':object,'company_id':object}, \
                  usecols=[1,2,3,4,5,6,7,8,10,11,12,13,26])

# %%
doc_df = paid[paid['npi']==str(1922188184)].groupby(['npi','fn','ln','year','company']).agg({'amount':'sum'}).reset_index()

# %%
tb = pd.pivot_table(doc_df, index=['year'],columns='company',values=['amount']).reset_index()

# %%
by_company = tb.copy()

# %%
by_company.columns = by_company.columns.droplevel()
by_company.columns = ['year']+list(by_company.columns)[1:]

# %%
by_company
# Out:
#    year   ABBVIE  ACTAVIS PHARMA  AMARIN PHARMA  ARBOR PHARMACEUTICALS  \
# 0  2013   98.030          17.220         30.820                    NaN
# 1  2014  313.320          39.910         42.375                  39.62
# 2  2015  199.235          76.095         17.200                  62.12
#
#    ASTELLAS PHARMA US  ASTRAZENECA PHARMACEUTICALS  AUXILIUM PHARMACEUTICALS  \
# 0               10.24                       37.970                     98.55
# 1               23.31                      492.600                     60.31
# 2               22.83                      435.075                       NaN
#
#    AVANIR PHARMACEUTICALS  BOEHRINGER INGELHEIM PHARMACEUTICALS  \
# 0                   22.48                                36.335
# 1                  293.38                                42.285
# 2                  106.44                               120.005
#
#         ...          PFIZER  PURDUE PHARMA  SANOFIAVENTIS US  \
# ...

# %%
paid.head(2)
# Out:
#           npi         fn      ln                address          city state  \
# 0  1174629083     FATIMA  ASGHAR  94 OLD SHORT HILLS RD    LIVINGSTON    NJ
# 1  1386735850  RAGHUVEER   ANNAM      290 RED SCHOOL LN  PHILLIPSBURG    NJ
#
#      zip                                          specialty  \
# 0  07039  Allopathic & Osteopathic Physicians|Internal M...
# 1  08865  Allopathic & Osteopathic Physicians|Internal M...
#
#                   company  amount                        form  \
# 0  FOREST PHARMACEUTICALS   14.83  In-kind items and services
# 1  FOREST PHARMACEUTICALS   72.90  In-kind items and services
#
#               nature  year
# 0  Food and Beverage  2013
# 1  Food and Beverage  2013

# %%
len(by_company.columns)
# Out:
# 41

# %%
df = pd.read_csv('/Users/kunal/Downloads/pay_script_full_onlypaid.csv',dtype={'npi':object})
df = df.iloc[:,:5]
df.head(2)
# Out:
#    year         npi         fn        ln  recieved_payments
# 0  2013  1003002072  ALEXANDER  GOTESMAN               True
# 1  2013  1003029836     THOMAS   MUELLER               True

# %%
def makelist(df):
    l =[]
    for i in range(len(df.columns)):
        l.append(df.iloc[:,i])
    return l

# %%
makelist(paid.iloc[:,:2])
# Out:
# [0         1174629083
#  1         1386735850
#  2         1659372829
#  3         1659372829
#  4         1912047754
#  5         1073624698
#  6         1225036866
#  7         1568400752
#  8         1568400752
#  9         1174524045
#  10        1972527950
#  11        1972527950
#  12        1972527950
#  13        1255407367
#  14        1518920925
#  15        1184937930
#  16        1689658460
#  17        1386726230
#  18        1184792814
#  19        1306838305
#  20        1043263916
#  21        1114985942
#  22        1205842473
#  23        1912960436
#  24        1720004021
#  25        1669523445
#  26        1801943303
#  27        1841215969
#  28        1922075373
#  29        1922075373
#               ...
#  926986    1366494486
#  926987    1063608065
#  926988    1063608065
#  926989    1164422788
#  926990    1841233418
#  926991    1841233418
#  926992    1841222502
#  926993    1841222502
#  926994    1841222502
#  926995    1841222502
# ...

# %%
[paid.npi, paid.fn]
# Out:
# [0         1174629083
#  1         1386735850
#  2         1659372829
#  3         1659372829
#  4         1912047754
#  5         1073624698
#  6         1225036866
#  7         1568400752
#  8         1568400752
#  9         1174524045
#  10        1972527950
#  11        1972527950
#  12        1972527950
#  13        1255407367
#  14        1518920925
#  15        1184937930
#  16        1689658460
#  17        1386726230
#  18        1184792814
#  19        1306838305
#  20        1043263916
#  21        1114985942
#  22        1205842473
#  23        1912960436
#  24        1720004021
#  25        1669523445
#  26        1801943303
#  27        1841215969
#  28        1922075373
#  29        1922075373
#               ...
#  926986    1366494486
#  926987    1063608065
#  926988    1063608065
#  926989    1164422788
#  926990    1841233418
#  926991    1841233418
#  926992    1841222502
#  926993    1841222502
#  926994    1841222502
#  926995    1841222502
# ...

# %%
df = pd.DataFrame(['1386735850', 'http://duckduckgo.com'])

def make_clickable(val):
    return '<a href="../../graph/npi/{}">{}</a>'.format(val,val)

df.style.format(make_clickable)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_24cc0be2_6803_11e8_85a4_6c4008a3d3c2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_24cc0be2_6803_11e8_85a4_6c4008a3d3c2level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_24cc0be2_6803_11e8_85a4_6c4008a3d3c2row0_col0" class="data row0 col0" ><a href="http://127.0.0.1:5000/graph/npi/1386735850">1386735850</a></td>
#     </tr>    <tr>
#         <th id="T_24cc0be2_6803_11e8_85a4_6c4008a3d3c2level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_24cc0be2_6803_11e8_85a4_6c4008a3d3c2row1_col0" class="data row1 col0" ><a href="http://127.0.0.1:5000/graph/npi/http://duckduckgo.com">http://duckduckgo.com</a></td>
#     </tr></tbody>
# </table>

# %%
paid
# Out:
#                npi         fn           ln  \
# 0       1174629083     FATIMA       ASGHAR
# 1       1386735850  RAGHUVEER        ANNAM
# 2       1659372829     DEEPAK         AMIN
# 3       1659372829     DEEPAK         AMIN
# 4       1912047754     AURORA    ANDREESCU
# 5       1073624698   JEBAMONI      AMBROSE
# 6       1225036866     DONALD     AUERBACH
# 7       1568400752    EUGENIA       BABIAK
# 8       1568400752    EUGENIA       BABIAK
# 9       1174524045   EMMANUEL        AYDIN
# 10      1972527950     MAZHAR       ELAMIR
# 11      1972527950     MAZHAR       ELAMIR
# 12      1972527950     MAZHAR       ELAMIR
# 13      1255407367      CAROL   DOBRZYNSKI
# 14      1518920925   CRISTIAN       ENESCU
# 15      1184937930      ANILA       FAIZAN
# 16      1689658460       PAUL       KAISER
# 17      1386726230      JOVEN        DUNGO
# 18      1184792814    BARBARA    ETHERIDGE
# 19      1306838305  CHRISTIAN      ELLISON
# 20      1043263916       MARK   DOMBROWSKI
# ...

# %%
def linkup(x):
    for col in x.index:
        if col == 'npi':
            paid2.at[col,str(x.name)] = '<a href="../../graph/npi/{}">{}</a>'.format(x[col],x[col])
        else:
            paid2.at[col,str(x.name)] = '<a href="../../graph/npi/{}">{}</a>'.format(x['npi'],x[col])
# Out:
#   File "<ipython-input-59-29ff3235f59f>", line 4
#     return paid2.at[col,str(x.name)] = '<a href="../../graph/npi/{}">{}</a>'.format(x[col],x[col])
#                                      ^
# SyntaxError: invalid syntax

# %%
def linkup(x):
    for ind in x.index:
        for col in x.columns:
            if col == 'npi':
                x.at[ind,col] = '<a href="../../graph/npi/{}">{}</a>'.format(x.at[ind,col],x.at[ind,col])
            else:
                x.at[ind,col] = ('<a href="../../graph/npi/{}">{}</a>'.format(x.at[ind,'npi'],x.at[ind,col]))

# %%
linkup(paid2)

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',
                            dtype={'payment_id':object,'zip':object,'npi':object,'company_id':object}, \
                  usecols=[1,2,3,4,5,6,7,8])

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',nrows=2)

# %%
paid2
# Out:
#                                                  npi  \
# 0  <a href="../../graph/npi/1174629083">117462908...
# 1  <a href="../../graph/npi/1386735850">138673585...
#
#                                                   fn  \
# 0  <a href="../../graph/npi/<a href="../../graph/...
# 1  <a href="../../graph/npi/<a href="../../graph/...
#
#                                                   ln  \
# 0  <a href="../../graph/npi/<a href="../../graph/...
# 1  <a href="../../graph/npi/<a href="../../graph/...
#
#                                              address  \
# 0  <a href="../../graph/npi/<a href="../../graph/...
# 1  <a href="../../graph/npi/<a href="../../graph/...
#
#                                                 city  \
# 0  <a href="../../graph/npi/<a href="../../graph/...
# 1  <a href="../../graph/npi/<a href="../../graph/...
#
#                                                state  \
# 0  <a href="../../graph/npi/<a href="../../graph/...
# ...

# %%
x = paid2.values.tolist()
x.insert(0,paid2.columns.tolist())

# %%
paid = pd.read_csv('/Users/kunal/Downloads/pay_script_full_onlypaid.csv',dtype={'npi':object},usecols=[1,2,3,5,6,7,8], nrows=10)

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',usecols=[1])

# %%
paid.head(2)
# Out:
#           npi         fn      ln                address          city state  \
# 0  1174629083     FATIMA  ASGHAR  94 OLD SHORT HILLS RD    LIVINGSTON    NJ
# 1  1386735850  RAGHUVEER   ANNAM      290 RED SCHOOL LN  PHILLIPSBURG    NJ
#
#     zip                                          specialty
# 0  7039  Allopathic & Osteopathic Physicians|Internal M...
# 1  8865  Allopathic & Osteopathic Physicians|Internal M...

# %%
paid2.at[0,'npi'],paid2.at[0,'fn']
# Out:
# ('1003002072', 'ALEXANDER')

# %%
'<a href="../../graph/npi/{}">{}</a>'.format(paid2.at[0,'npi'],paid2.at[0,'fn'])
# Out:
# '<a href="../../graph/npi/1003002072">ALEXANDER</a>'

# %%
'<a href="../../graph/npi/{}">{}</a>'.format(paid2.at[0,'npi'],paid2.at[0,'npi'])
# Out:
# '<a href="../../graph/npi/1003002072">1003002072</a>'

# %%
"<a href='../../graph/npi/{}'>{}</a>"".format(paid2.at[0,'npi'],paid2.at[0,'year'])
# Out:
# '<a href="../../graph/npi/1003002072">2013</a>'

# %%
paid = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv',dtype={'npi':object},usecols=[1,2])

# %%
scriptsnjfull = pd.read_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv',dtype={'npi':object,'zip':object})

# %%
paid_npis = paid.groupby('npi')['fn'].count().to_frame().reset_index()

# %%
scripts_npis = scriptsnjfull.groupby('npi')['nppes_provider_last_org_name'].count().to_frame().reset_index().drop('nppes_provider_last_org_name',axis=1)

# %%
result = pd.concat([scripts_npis,paid_npis])

# %%
len(result)
# Out:
# 44016

# %%
len(paid_npis),len(scripts_npis),(len(paid_npis)+len(scripts_npis))
# Out:
# (16482, 27534, 44016)

# %%
npis = result.groupby('npi')['fn'].count().to_frame().reset_index().drop('fn',axis=1)

# %%
npis.head(2)
# Out:
#           npi
# 0  1003001678
# 1  1003002072

# %%
len(npis)
# Out:
# 27534

# %%
scriptsnjfull.head()
# Out:
#           npi       ln       fn     city state specialty_description  year  \
# 0  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 1  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 2  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 3  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 4  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
#
#    recieved_payments  total_claim_count  amount_brand  \
# 0               True                 48            48
# 1               True                 16             0
# 2               True                 27             0
# 3               True                 34             0
# 4               True                 29            29
#
#                     drug_name                generic_name  brand_drug?  \
# 0                      VIAGRA                  SILDENAFIL         True
# ...

# %%
scriptsnjfull.rename(columns=newcols,inplace=True)

# %%
scriptsnjfull.to_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv',index=False)

# %%
doc_info = pd.read_csv('/Volumes/Seagate/Galvanize/nj_scripts_all_years.csv',dtype={'npi':object,'zip':object},usecols=[0,1,2,3,4,5])

# %%
doc_info = scriptsnjfull.copy()

# %%
doc_info.drop(['recieved_payments','total_claim_count','amount_brand','drug_name','generic_name','brand_drug?','total_day_supply','total_drug_cost'],axis=1,inplace=True)

# %%
newcols={'npi':'NPI',"fn":'First Name','ln':'Last Name', \
        'city':'City','state':'State','specialty_description':'Specialty Description'}

# %%
doc_info.to_csv('/Volumes/Seagate/Galvanize/nj_doc_info.csv',index=False)

# %%
doc_info.head(2)
# Out:
#           NPI Last Name First Name     City State Specialty Description  year
# 0  1528036670   LANTERI    VINCENT  MAYWOOD    NJ               Urology  2013
# 1  1528036670   LANTERI    VINCENT  MAYWOOD    NJ               Urology  2013

# %%
docs = doc_info.groupby(['NPI','Last Name','First Name','City','State','Specialty Description'])['year'].nunique().to_frame().reset_index()

# %%
doc_info2=doc_info.copy()
doc_info2.drop(['year','State'],axis=1,inplace=True)

# %%
result = docs.merge(doc_info2, how='inner',left_on='NPI',right_on='NPI')

# %%
len(docs.NPI.unique()), len(docs)
# Out:
# (27534, 29381)

# %%
docs.head()
# Out:
#           NPI Last Name First Name          City State Specialty Description  \
# 0  1003001678    EIRICH    REBECCA  TURNERSVILLE    NJ    Nurse Practitioner
# 1  1003002072  GOTESMAN  ALEXANDER      HAMILTON    NJ               Urology
# 2  1003002858    GIBSON        AMY    PLAINFIELD    NJ    Nurse Practitioner
# 3  1003011891     SPIRA       ETAN    BELLEVILLE    NJ      Gastroenterology
# 4  1003012410    TINDOC   LORELANE       CLIFTON    NJ       Family Practice
#
#    year
# 0     1
# 1     3
# 2     3
# 3     2
# 4     3

# %%
snpi[:1].to_dict('index')
# Out:
# {0: {'Authorized Official Credential Text': nan,
#   'Authorized Official First Name': nan,
#   'Authorized Official Last Name': nan,
#   'Authorized Official Middle Name': nan,
#   'Authorized Official Name Prefix Text': nan,
#   'Authorized Official Name Suffix Text': nan,
#   'Authorized Official Telephone Number': nan,
#   'Authorized Official Title or Position': nan,
#   'Employer Identification Number (EIN)': nan,
#   'Entity Type Code': 1,
#   'Healthcare Provider Primary Taxonomy Switch_1': 'Y',
#   'Healthcare Provider Primary Taxonomy Switch_10': nan,
#   'Healthcare Provider Primary Taxonomy Switch_11': nan,
#   'Healthcare Provider Primary Taxonomy Switch_12': nan,
#   'Healthcare Provider Primary Taxonomy Switch_13': nan,
#   'Healthcare Provider Primary Taxonomy Switch_14': nan,
#   'Healthcare Provider Primary Taxonomy Switch_15': nan,
#   'Healthcare Provider Primary Taxonomy Switch_2': nan,
#   'Healthcare Provider Primary Taxonomy Switch_3': nan,
# ...

# %%
len(npi)
# Out:
# 4188312

# %%
len(npi['NPI'].unique())
# Out:
# 4188312

# %%
#Loading in All Npis to make a file of basic info of all NJ docs (the reason I can't use other CSVs I have is some docs have mulitple specialties & such which this will cover)
npi = pd.read_csv('/Volumes/Seagate/Galvanize/NPPES_Data_Dissemination_May_2018/npidata_pfile_20050523-20180513.csv', \
                  usecols=['Entity Type Code','NPI', 'Provider Gender Code', \
                           'Provider First Name','Provider Last Name (Legal Name)', \
                           'Provider Business Practice Location Address Postal Code', \
                           'Provider First Line Business Practice Location Address', \
                           'Provider Business Practice Location Address State Name', \
                           'Provider Credential Text', 'Provider Business Practice Location Address City Name'], \
                           dtype = {'Provider Business Practice Location Address Postal Code':object})

# %%
#Grabbing only the individuals from the npi database, so I can remove orgs from the dataframe
npi = npi[npi['Entity Type Code'].isin([1.0])]

# %%
npi.drop(['Entity Type Code'],inplace=True,axis=1)

# %%
newcols = {'Provider Last Name (Legal Name)':'Last Name','Provider First Name':'First Name', \
           'Provider Credential Text':'Type','Provider First Line Business Practice Location Address':'Address', \
          'Provider Business Practice Location Address State Name':'State','Provider Business Practice Location Address Postal Code':'Zip Code', \
          'Provider Gender Code':'Gender','Provider Business Practice Location Address City Name':'City'}
npi.rename(columns=newcols,inplace=True)

# %%
npi = npi[npi['State'].isin(['NJ'])]

# %%
npi.head(1)
# Out:
#            NPI Last Name First Name  Type           Address    City State  \
# 30  1477556421      ROTH     STEVEN  O.D.  1107 MANTUA PIKE  MANTUA    NJ
#
#      Zip Code Gender
# 30  080511606      M

# %%
npi2 = npi.copy()

# %%
npi['Zip Code'] = npi['Zip Code'].apply(lambda x: x[:5])

# %%
#Cleaning up how I want the columns arranged
npi = npi[npi.columns.tolist()[:1]+npi.columns.tolist()[2:3]+ \
          npi.columns.tolist()[1:2] + npi.columns.tolist()[3:4] + \
          npi.columns.tolist()[-1:] + npi.columns.tolist()[4:-1]]

# %%
scriptsnjfull.npi.unique()
# Out:
# array(['1528036670', '1699730937', '1346238334', ..., '1942382148',
#        '1114265642', '1982689352'], dtype=object)

# %%
npi = npi[npi['NPI'].isin(scriptsnjfull.npi.unique())]

# %%
#Saving as a csv for future use
npi.to_csv('/Volumes/Seagate/Galvanize/nj_doc_info.csv',index=False)

# %%
import numpy as np
import pandas as pd

npi = pd.read_csv('/Volumes/Seagate/Galvanize/nj_doc_info.csv',dtype={'Zip Code':object,'NPI':object})

# %%
npi.head(2)
# Out:
#           NPI First Name          Last Name  Type Gender           Address  \
# 0  1477556421     STEVEN               ROTH  O.D.      M  1107 MANTUA PIKE
# 1  1508869553        LEE  VAN HOUTEN-SAUTER  D.O.      F       220 PINE ST
#
#            City State Zip Code
# 0        MANTUA    NJ    08051
# 1  WILLIAMSTOWN    NJ    08094

# %%
npi[npi['First Name']=='']
# Out:
# Empty DataFrame
# Columns: [NPI, First Name, Last Name, Type, Gender, Address, City, State, Zip Code]
# Index: []

# %%
d = {'fn':'hi','ln':2,'no':''}

# %%
d_true_values = {}
for key, value in d.items():
    if value:
        d_true_values[key] = value

# %%
d_true_values
# Out:
# {'fn': 'hi', 'ln': 2}

# %%
x = str(d_true_values.pop('ln', None))

# %%
x
# Out:
# '2'

# %%
for x in d:
    print(str(d[x]).upper())
# Out:
# HI
# 2

# %%
d
# Out:
# {'fn': '', 'ln': 2}

# %%
npi.columns
# Out:
# Index(['NPI', 'First Name', 'Last Name', 'Type', 'Gender', 'Address', 'City',
#        'State', 'Zip Code'],
#       dtype='object')

# %%
bold = lambda x: '<b>'+x+'</b>'

# %%
len(npi.columns)/2
# Out:
# 4.5

# %%
[[x,y]*len(npi.columns)/2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-8a93316e4eb4> in <module>()
# ----> 1 [[x,y]*len(npi.columns)/2]
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
x = 'hi'
y = 'u'

# %%
[x,y]
# Out:
# ['hi', 'u']

# %%
print([['white','lightgrey'] * int((len(npi.columns)/2))+['white']])
print([[x,y] * int((len(npi.columns)/2))])
# Out:
# [['white', 'lightgrey', 'white', 'lightgrey', 'white', 'lightgrey', 'white', 'lightgrey', 'white']]
# [['hi', 'u', 'hi', 'u', 'hi', 'u', 'hi', 'u']]

# %%
if len(npi) %2 !=0:
    print('hi')
# Out:
# hi

# %%
def l():
    if len(npi) %2 !=0:
        return([['white','lightgrey'] * int((len(npi.columns)/2))+['white']])
    else:
        return([['white','lightgrey'] * int((len(npi.columns)/2))])

# %%
l()
# Out:
# [['white',
#   'lightgrey',
#   'white',
#   'lightgrey',
#   'white',
#   'lightgrey',
#   'white',
#   'lightgrey',
#   'white']]

# %%
scriptsnjfull.head(2)
# Out:
#           npi       ln       fn     city state specialty_description  year  \
# 0  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 1  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
#
#    recieved_payments  total_claim_count  amount_brand  \
# 0               True                 48            48
# 1               True                 16             0
#
#                     drug_name                generic_name  brand_drug?  \
# 0                      VIAGRA                  SILDENAFIL         True
# 1  CLOTRIMAZOLE BETAMETHASONE  CLOTRIMAZOLE BETAMETHASONE        False
#
#    total_day_supply  total_drug_cost
# 0              1481          8957.33
# 1               367           806.59

# %%
scriptsnjfull[scriptsnjfull['ln']=='KABNICK']
# Out:
#                 npi       ln      fn        city state specialty_description  \
# 1281485  1477533925  KABNICK  LOWELL  MORRISTOWN    NJ       General Surgery
# 1929976  1477533925  KABNICK  LOWELL  MORRISTOWN    NJ       General Surgery
#
#          year  recieved_payments  total_claim_count  amount_brand  \
# 1281485  2014               True                 21             0
# 1929976  2015               True                 39             0
#
#                    drug_name         generic_name  brand_drug?  \
# 1281485       ALPRAZOLAM ODT       ALPRAZOLAM ODT        False
# 1929976  ALPRAZOLAM INTENSOL  ALPRAZOLAM INTENSOL        False
#
#          total_day_supply  total_drug_cost
# 1281485                26            40.93
# 1929976                49            62.11
