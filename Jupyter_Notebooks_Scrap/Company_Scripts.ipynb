# %%
import pandas as pd
import numpy as np
import re
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
pays = pd.read_csv('/Volumes/Seagate/Galvanize/nj_payments_all_years_consl.csv', \
                   usecols=['company','amount','npi','year','payment_id'])

# %%
pays.head(2)
# Out:
#    payment_id         npi                 company  amount  year
# 0    235088.0  1174629083  FOREST PHARMACEUTICALS   14.83  2013
# 1    334868.0  1386735850  FOREST PHARMACEUTICALS   72.90  2013

# %%
pay_by_comp = pays.groupby(['company']).agg({"amount": np.sum, "npi": pd.Series.nunique,'payment_id':'count'}).reset_index()
top10 = pay_by_comp.sort_values(['amount','npi','payment_id'],ascending=False).iloc[:10]

# %%
top10
 """),
    go.Bar(
        x=top10['company'],
        y=top10['npi'],
        name='Number Doctors Paid'
    ),
    go.Bar(
        x=top10['company'],
        y=top10['payment_id'],
        name='Number Payments'
    ),"""
# Out:
#                                   company      amount   npi  payment_id
# 82            ASTRAZENECA PHARMACEUTICALS  4037326.89  5358       63142
# 408               JANSSEN PHARMACEUTICALS  3570202.64  4683       45290
# 5                                  ABBVIE  3304520.11  2918       27077
# 857                ZIMMER BIOMET HOLDINGS  2829123.15  1015        3342
# 775              TEVA PHARMACEUTICALS USA  2165207.78  2034       18525
# 286                        ER SQUIBB SONS  1960920.85  3277       20091
# 623                                PFIZER  1945655.35  4571       34922
# 138  BOEHRINGER INGELHEIM PHARMACEUTICALS  1784204.80  3084       30656
# 760        TAKEDA PHARMACEUTICALS AMERICA  1713637.86  3233       24982
# 608         OTSUKA AMERICA PHARMACEUTICAL  1701228.73  1910       12052

# %%
data = [go.Bar(
        x=top10['company'],
        y=top10['amount'],
        name='Total Amount Paid',
        marker=dict(color=['FireBrick','Navy','Green','DarkMagenta',
                           'DarkOrange','Indigo','LightSkyBlue','DarkSlateGrey',
                           'MediumVioletRed','Peru']),)]

layout = go.Layout(
    title='Highest Paying Companies'
)

fig = go.Figure(data=data, layout=layout)

plotly.offline.plot(fig,filename='top10companies')
# Out:
# <div id="084c2cf6-2321-4f7e-bce3-3464a9e16794" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("084c2cf6-2321-4f7e-bce3-3464a9e16794", [{"type": "bar", "x": ["ASTRAZENECA PHARMACEUTICALS", "JANSSEN PHARMACEUTICALS", "ABBVIE", "ZIMMER BIOMET HOLDINGS", "TEVA PHARMACEUTICALS USA", "ER SQUIBB SONS", "PFIZER", "BOEHRINGER INGELHEIM PHARMACEUTICALS", "TAKEDA PHARMACEUTICALS AMERICA", "OTSUKA AMERICA PHARMACEUTICAL"], "y": [4037326.8899999694, 3570202.640000045, 3304520.109999995, 2829123.150000006, 2165207.779999979, 1960920.8499999812, 1945655.349999972, 1784204.799999967, 1713637.8599999729, 1701228.7300000107], "name": "Total Amount Paid", "marker": {"color": ["FireBrick", "Navy", "Green", "DarkMagenta", "DarkOrange", "Indigo", "LightSkyBlue", "DarkSlateGrey", "MediumVioletRed", "Peru"]}}], {"title": "Highest Paying Companies"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
meds = pd.read_csv('/Volumes/Seagate/Galvanize/Drug_Products_in_the_Medicaid_Drug_Rebate_Program.csv',
                  usecols=['NDC','Labeler Name','FDA Product Name','Year'])

# %%
meds.head(2)
# Out:
#    Year                             Labeler Name      NDC  \
# 0  2014  ELI LILLY AND COMPANY                    2120001
# 1  2014  ELI LILLY AND COMPANY                    2140701
#
#                                     FDA Product Name
# 0  AMYVID                                        ...
# 1  QUINIDINE GLUCONATE                           ...

# %%
#Removing excess spacing & any symbols
meds['FDA Product Name'] = [re.sub(r'[^\w\s]','',str(x).upper()) for x in meds['FDA Product Name']]
meds['FDA Product Name'] = meds['FDA Product Name'].str.strip()
meds['Labeler Name'] = [re.sub(r'[^\w\s]','',str(x).upper()) for x in meds['Labeler Name']]
meds['Labeler Name'] = meds['Labeler Name'].str.strip()

# %%
meds.head(2)
# Out:
#    Year           Labeler Name      NDC     FDA Product Name
# 0  2014  ELI LILLY AND COMPANY  2120001               AMYVID
# 1  2014  ELI LILLY AND COMPANY  2140701  QUINIDINE GLUCONATE

# %%
medsgrp = meds.groupby(['FDA Product Name','Labeler Name'])['NDC'].nunique().to_frame().reset_index()

# %%
print(len(medsgrp))
medsgrp.head()
# Out:
# 45533
#                                     FDA Product Name  \
# 0  0000000000000000000000000000000000000ONIVYDE 4...
# 1  0075 KCL IN 5 DEXTROSE AND 045 NACL INJECTION USP
# 2                   015 KCL IN 09 NACL INJECTION USP
# 3   015 KCL IN 5 DEXTROSE AND 020 NACL INJECTION USP
# 4   015 KCL IN 5 DEXTROSE AND 033 NACL INJECTION USP
#
#                     Labeler Name  NDC
# 0  MERRIMACK PHARMACEUTICALS INC    1
# 1            B BRAUN MEDICAL INC    1
# 2            B BRAUN MEDICAL INC    1
# 3            B BRAUN MEDICAL INC    2
# 4            B BRAUN MEDICAL INC    1

# %%
#Only getting brand name drugs
scripts = scripts[scripts['drug_name']!=scripts['generic_name']]

# %%
scriptsgrp = scripts.groupby('drug_name')['generic_name'].nunique().to_frame().reset_index()

# %%
print(len(scriptsgrp))
scriptsgrp.head()
# Out:
# 1448
#           drug_name  generic_name
# 0           ABILIFY             1
# 1  ABILIFY DISCMELT             1
# 2  ABILIFY MAINTENA             1
# 3          ABRAXANE             1
# 4           ABSTRAL             1

# %%
common = scriptsgrp.merge(medsgrp,left_on='drug_name',right_on='FDA Product Name')

# %%
scripts[(~scripts.drug_name.isin(common.drug_name))]
# Out:
#                drug_name                    generic_name
# 0                 VIAGRA                      SILDENAFIL
# 4               ANDROGEL                    TESTOSTERONE
# 7               VESICARE           SOLIFENACIN SUCCINATE
# 12                FLOMAX                      TAMSULOSIN
# 15               RAPAFLO                       SILODOSIN
# 19               AVODART                     DUTASTERIDE
# 20                TOVIAZ           FESOTERODINE FUMARATE
# 53              CELEBREX                       CELECOXIB
# 55                LYRICA                      PREGABALIN
# 58              LIDODERM               LIDOCAINE VISCOUS
# 59              VOLTAREN               DICLOFENAC SODIUM
# 61              PERCOCET         OXYCODONE ACETAMINOPHEN
# 65               ENDOCET         OXYCODONE ACETAMINOPHEN
# 70                 OPANA                     OXYMORPHONE
# 77             OXYCONTIN                       OXYCODONE
# 81             OXYCONTIN                       OXYCODONE
# 83                NEXIUM          ESOMEPRAZOLE MAGNESIUM
# 89              REVLIMID                    LENALIDOMIDE
# 93              FASLODEX                     FULVESTRANT
# 94               GLEEVEC               IMATINIB MESYLATE
# 97                DIOVAN                       VALSARTAN
# 101            SYNTHROID            LEVOTHYROXINE SODIUM
# 115              VYTORIN           EZETIMIBE SIMVASTATIN
# 116                DIGOX                         DIGOXIN
# 118         VENTOLIN HFA               ALBUTEROL SULFATE
# 120                ZETIA                       EZETIMIBE
# 123        ADVAIR DISKUS          FLUTICASONE SALMETEROL
# 124           PROAIR HFA               ALBUTEROL SULFATE
# 128              CRESTOR            ROSUVASTATIN CALCIUM
# 137               TOPROL            METOPROLOL SUCCINATE
# ...                  ...                             ...
# 1934575          SPIRIVA              TIOTROPIUM BROMIDE
# 1934605         SENSIPAR                      CINACALCET
# 1934608        SYNTHROID            LEVOTHYROXINE SODIUM
# 1934612          CRESTOR            ROSUVASTATIN CALCIUM
# 1934642         TRINESSA  NORGESTIMATE ETHINYL ESTRADIOL
# 1934650   ARMOUR THYROID                    THYROID PORK
# 1934657         PREMARIN            ESTROGENS CONJUGATED
# 1934660         PREMARIN            ESTROGENS CONJUGATED
# 1934661          VAGIFEM                       ESTRADIOL
# 1934689          VAGIFEM                       ESTRADIOL
# 1934693         PREMARIN            ESTROGENS CONJUGATED
# 1934718          VAGIFEM                       ESTRADIOL
# 1934730        SYNTHROID            LEVOTHYROXINE SODIUM
# 1934744   ARMOUR THYROID                    THYROID PORK
# 1934752         VESICARE           SOLIFENACIN SUCCINATE
# 1934772         SUBOXONE          BUPRENORPHINE NALOXONE
# 1934774           NEXIUM          ESOMEPRAZOLE MAGNESIUM
# 1934776         CRYSELLE    NORGESTREL ETHINYL ESTRADIOL
# 1934778           SUPREP   SODIUM POTASSIUM MAG SULFATES
# 1934829  DENTA 5000 PLUS                 SODIUM FLUORIDE
# 1934854  LANTUS SOLOSTAR  INSULIN GLARGINE HUM REC ANLOG
# 1934856         BYSTOLIC                       NEBIVOLOL
# 1934861           SANTYL    COLLAGENASE CLOSTRIDIUM HIST
# 1934874         CELEBREX                       CELECOXIB
# 1934877  RISPERDAL M TAB                 RISPERIDONE ODT
# 1934901         PREMARIN            ESTROGENS CONJUGATED
# 1934902          CRESTOR            ROSUVASTATIN CALCIUM
# 1934907         SUBOXONE          BUPRENORPHINE NALOXONE
# 1934947        LEVORA 28  LEVONORGESTREL ETHIN ESTRADIOL
# 1934965         ZOSTAVAX             ZOSTER VACCINE LIVE
#
# [416706 rows x 2 columns]

# %%
medsgrp['VIAGRA']
# Out:
# Empty DataFrame
# Columns: [FDA Product Name, Labeler Name, NDC]
# Index: []

# %%
medsgrp[medsgrp['FDA Product Name'].str.contains('VIAGRA')].groupby('Labeler Name')['NDC'].count()
# Out:
#                           FDA Product Name Labeler Name  NDC
# 43965            VIAGRA SILDENAFIL CITRATE   PFIZER INC    5
# 43966  VIAGRA SILDENAFIL CITRATE 100MG TAB   PFIZER INC    2
# 43967   VIAGRA SILDENAFIL CITRATE 50MG TAB   PFIZER INC    2

# %%
scriptsgrp.to_csv('/Volumes/Seagate/Galvanize/brand_drugs_scripts.csv',index=False)

# %%
medsgrp.to_csv('/Volumes/Seagate/Galvanize/medicare_drugs.csv',index=False)

# %% [markdown]
# ## <font color='blue'>Linking companies to their drugs</font>

# %%
import pandas as pd
import numpy as np

# %%
scriptsgrp= pd.read_csv('/Volumes/Seagate/Galvanize/brand_drugs_scripts.csv')
# Out:
#           drug_name  generic_name
# 0           ABILIFY             1
# 1  ABILIFY DISCMELT             1

# %%
medsgrp= pd.read_csv('/Volumes/Seagate/Galvanize/medicare_drugs.csv')

# %%
medsgrp[medsgrp['FDA Product Name'].str.contains('VIAGRA')].groupby('Labeler Name')['NDC'].count()
# Out:
# Labeler Name
# PFIZER INC    3
# Name: NDC, dtype: int64

# %% [markdown]
# Make a dict that has:
#
#     keys = COMPANY
#     values = ALL DRUGS
#
# if the drug is in the k, v for that company:
#
#     New Col [company] = Company

# %% [markdown]
# groupby company, iterate through company.unique, take company & index by it, for each company iterate through the drugs & add it to the values of that company
#
# Map based on iff the drug is

# %%
'VIAGRA'.str.contains('VIAGRA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1cbd268326e4> in <module>()
# ----> 1 'VIAGRA'.str.contains('VIAGRA')
#
# AttributeError: 'str' object has no attribute 'str'

# %%
viag = ['VIAGRA SILDENAFIL CITRATE','VIAGRA SILDENAFIL CITRATE 100MG TAB','VIAGRA SILDENAFIL CITRATE 50MG TAB']

# %%
viag
# Out:
# ['VIAGRA SILDENAFIL CITRATE',
#  'VIAGRA SILDENAFIL CITRATE 100MG TAB',
#  'VIAGRA SILDENAFIL CITRATE 50MG TAB']

# %%
lambda x: map(lambda w : v + w, y), x)

# %% [markdown]
# for every drug:
#     medsgrp[medsgrp['FDA Product Name'].str.contains(DRUG)].groupby('Labeler Name')['NDC'].count().to_frame().reset_index()

# %%
medsgrp[medsgrp['Labeler Name'].str.contains('VIDARA')]
# Out:
#                  FDA Product Name             Labeler Name  NDC
# 601  ACTIMMUNE INTERFERON GAMMA1B  VIDARA THERAPEUTICS INC    2

# %%
x = 
        medsgrp[medsgrp['FDA Product Name'].str.contains('VIAGRA')].groupby('Labeler Name')['NDC'].count().to_frame(). \
        reset_index().sort_values('NDC',ascending=False).reset_index().drop('index',axis=1)['Labeler Name'][0]

# %%
d = {}
def company_drug(x):
    if x['drug_name'] not in d:
        try:
            df = medsgrp[medsgrp['FDA Product Name'].str.contains \
                                        (x['drug_name'])].groupby('Labeler Name')['NDC'].count()
            df = df.to_frame().reset_index().sort_values('NDC',ascending=False).reset_index().drop('index',axis=1)
            d[x['drug_name']] = df['Labeler Name'][0]
        except IndexError:
            df[x['drug_name']] = np.nan

# %%
scriptsgrp.apply(company_drug,axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 1418    None
# 1419    None
# 1420    None
# 1421    None
# 1422    None
# 1423    None
# 1424    None
# 1425    None
# 1426    None
# 1427    None
# 1428    None
# 1429    None
# 1430    None
# 1431    None
# 1432    None
# 1433    None
# 1434    None
# 1435    None
# 1436    None
# 1437    None
# 1438    None
# 1439    None
# 1440    None
# 1441    None
# 1442    None
# 1443    None
# 1444    None
# 1445    None
# 1446    None
# 1447    None
# Length: 1448, dtype: object

# %%
scriptsgrp["company"] = scriptsgrp["drug_name"].map(d)

# %%
medsgrp[medsgrp['FDA Product Name'].str.contains('ABSTRAL')].groupby('Labeler Name')['NDC'].count().to_frame(). \
        reset_index().sort_values('NDC',ascending=False).reset_index().drop('index',axis=1)['Labeler Name']
# Out:
# 0        GALENA BIOPHARMA INC
# 1              PROSTRAKAN INC
# 2        SENTYNL THERAPEUTICS
# 3    SENTYNL THERAPEUTICS INC
# Name: Labeler Name, dtype: object

# %%
medsgrp['Labeler Name'][0]
# Out:
# 'MERRIMACK PHARMACEUTICALS INC'

# %%
script_and_company = scriptsgrp.copy()

# %%
script_company_dict = d

# %%
import pickle

# %%
script_and_company.fillna(value='UNKNOWN',inplace=True)

# %%
script_and_company.to_csv('/Volumes/Seagate/Galvanize/script_and_company.csv',index=False)

# %%
pickle.dump(script_company_dict, open('script_company_dict.pkl', 'wb'))

# %% [markdown]
# ## <font color='teal'>Graphing work, mainly for graphing the amount a company made off a drug</font>

# %%
scripts = pd.read_csv('/volumes/Seagate/Galvanize/nj_scripts_all_years.csv',usecols=['drug_name','generic_name','amount_brand','total_drug_cost'])

# %%
comp_scripts = scripts[scripts['amount_brand']!=0]

# %%
comp_scripts.head()
# Out:
#     amount_brand drug_name           generic_name  total_drug_cost
# 0             48    VIAGRA             SILDENAFIL          8957.33
# 4             29  ANDROGEL           TESTOSTERONE         17234.63
# 7             37  VESICARE  SOLIFENACIN SUCCINATE         13580.78
# 11            26    CIALIS              TADALAFIL          3348.48
# 12            23    FLOMAX             TAMSULOSIN          5060.75

# %%
comp_scripts["company"] = comp_scripts["drug_name"].map(d)
# Out:
# /Users/kunal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
comp_scripts.dropna(axis=0,how='any')
# Out:
#          amount_brand        drug_name                    generic_name  \
# 0                  48           VIAGRA                      SILDENAFIL
# 4                  29         ANDROGEL                    TESTOSTERONE
# 7                  37         VESICARE           SOLIFENACIN SUCCINATE
# 11                 26           CIALIS                       TADALAFIL
# 12                 23           FLOMAX                      TAMSULOSIN
# 15                 16          RAPAFLO                       SILODOSIN
# 19                 40          AVODART                     DUTASTERIDE
# 20                 19           TOVIAZ           FESOTERODINE FUMARATE
# 25                 13          VIGAMOX                    MOXIFLOXACIN
# 26                 41          LUMIGAN                     BIMATOPROST
# 27                 22       TRAVATAN Z                      TRAVOPROST
# 32                 11         TOBRADEX        TOBRAMYCIN DEXAMETHASONE
# 33                 34         RESTASIS                    CYCLOSPORINE
# 53                 47         CELEBREX                       CELECOXIB
# 55                143           LYRICA                      PREGABALIN
# 58                 54         LIDODERM               LIDOCAINE VISCOUS
# 59                 87         VOLTAREN               DICLOFENAC SODIUM
# 61                 13         PERCOCET         OXYCODONE ACETAMINOPHEN
# 63                 31         CYMBALTA                      DULOXETINE
# 65                 50          ENDOCET         OXYCODONE ACETAMINOPHEN
# 70                 27            OPANA                     OXYMORPHONE
# 77                 61        OXYCONTIN                       OXYCODONE
# 81                 13        OXYCONTIN                       OXYCODONE
# 83                 19           NEXIUM          ESOMEPRAZOLE MAGNESIUM
# 89                 46         REVLIMID                    LENALIDOMIDE
# 93                 13         FASLODEX                     FULVESTRANT
# 94                 15          GLEEVEC               IMATINIB MESYLATE
# 97                 39           DIOVAN                       VALSARTAN
# 101                18        SYNTHROID            LEVOTHYROXINE SODIUM
# 115                19          VYTORIN           EZETIMIBE SIMVASTATIN
# ...               ...              ...                             ...
# 1934650            13   ARMOUR THYROID                    THYROID PORK
# 1934657            14         PREMARIN            ESTROGENS CONJUGATED
# 1934660            11         PREMARIN            ESTROGENS CONJUGATED
# 1934661            21          VAGIFEM                       ESTRADIOL
# 1934689            11          VAGIFEM                       ESTRADIOL
# 1934693            11         PREMARIN            ESTROGENS CONJUGATED
# 1934718            11          VAGIFEM                       ESTRADIOL
# 1934719            19       TRAVATAN Z                      TRAVOPROST
# 1934728            48         RESTASIS                    CYCLOSPORINE
# 1934730            12        SYNTHROID            LEVOTHYROXINE SODIUM
# 1934744            11   ARMOUR THYROID                    THYROID PORK
# 1934752            23         VESICARE           SOLIFENACIN SUCCINATE
# 1934768            16         RESTASIS                    CYCLOSPORINE
# 1934772            47         SUBOXONE          BUPRENORPHINE NALOXONE
# 1934774            13           NEXIUM          ESOMEPRAZOLE MAGNESIUM
# 1934778            45           SUPREP   SODIUM POTASSIUM MAG SULFATES
# 1934787            11       TRAVATAN Z                      TRAVOPROST
# 1934806            11          LUMIGAN                     BIMATOPROST
# 1934808            11       TRAVATAN Z                      TRAVOPROST
# 1934829            13  DENTA 5000 PLUS                 SODIUM FLUORIDE
# 1934854            11  LANTUS SOLOSTAR  INSULIN GLARGINE HUM REC ANLOG
# 1934856            12         BYSTOLIC                       NEBIVOLOL
# 1934861            11           SANTYL    COLLAGENASE CLOSTRIDIUM HIST
# 1934874            12         CELEBREX                       CELECOXIB
# 1934876            12          TRUVADA         EMTRICITABINE TENOFOVIR
# 1934883            12           EVISTA                      RALOXIFENE
# 1934901            16         PREMARIN            ESTROGENS CONJUGATED
# 1934902            20          CRESTOR            ROSUVASTATIN CALCIUM
# 1934907            14         SUBOXONE          BUPRENORPHINE NALOXONE
# 1934950            11       TRAVATAN Z                      TRAVOPROST
#
#          total_drug_cost                                company
# 0                8957.33                             PFIZER INC
# 4               17234.63                             ABBVIE INC
# 7               13580.78                               ASTELLAS
# 11               3348.48                  ELI LILLY AND COMPANY
# 12               5060.75   BOEHRINGER INGELHEIM PHARMACEUTICALS
# 15               4242.73                      WATSON PHARMA INC
# 19               6418.34                        GLAXOSMITHKLINE
# 20               7328.35                             PFIZER INC
# 25               1320.04                 ALCON LABORATORIES INC
# 26               5446.44                           ALLERGAN INC
# 27               3366.02                 ALCON LABORATORIES INC
# 32               1791.06                 ALCON LABORATORIES INC
# 33              15079.11                           ALLERGAN INC
# 53               7882.12                             PFIZER INC
# 55              34086.25                             PFIZER INC
# 58              21118.40               ENDO PHARMACEUTICALS INC
# 59               9871.53               ENDO PHARMACEUTICALS INC
# 61              11837.44               ENDO PHARMACEUTICALS INC
# 63              13138.23                  ELI LILLY AND COMPANY
# 65               2259.20              QUALITEST PHARMACEUTICALS
# 70              14021.67               ENDO PHARMACEUTICALS INC
# 77              31955.43                       PURDUE PHARMA LP
# 81               4049.75                       PURDUE PHARMA LP
# 83               4170.61                         ASTRAZENECA LP
# 89             407878.60                    CELGENE CORPORATION
# 93              32468.44                         ASTRAZENECA LP
# 94             152963.70                               NOVARTIS
# 97               5449.03                               NOVARTIS
# 101               305.43                    ABBOTT LABORATORIES
# 115              3687.51                 MERCKSCHERINGPLOUGH JV
# ...                  ...                                    ...
# 1934650           585.01                FOREST LABORATORIES INC
# 1934657          2166.70                    AYERST LABORATORIES
# 1934660          3655.84                    AYERST LABORATORIES
# 1934661          3346.31                       NOVO NORDISK INC
# 1934689          2985.86                       NOVO NORDISK INC
# 1934693          2205.07                    AYERST LABORATORIES
# 1934718          4478.35                       NOVO NORDISK INC
# 1934719          4983.03                 ALCON LABORATORIES INC
# 1934728         17764.90                           ALLERGAN INC
# 1934730           364.62                    ABBOTT LABORATORIES
# 1934744           232.76                FOREST LABORATORIES INC
# 1934752          5662.59                               ASTELLAS
# 1934768          9588.96                           ALLERGAN INC
# 1934772         11453.32  RECKITT BENCKISER PHARMACEUTICALS INC
# 1934774          3202.35                         ASTRAZENECA LP
# 1934778          3578.31             BRAINTREE LABORATORIES INC
# 1934787          2102.31                 ALCON LABORATORIES INC
# 1934806          3446.28                           ALLERGAN INC
# 1934808          2903.42                 ALCON LABORATORIES INC
# 1934829            66.38             RISING PHARMACEUTICALS INC
# 1934854         13341.77                AVENTIS PHARMACEUTICALS
# 1934856          1123.44                FOREST LABORATORIES INC
# 1934861          2185.20                      SMITH  NEPHEW INC
# 1934874          2952.27                             PFIZER INC
# 1934876         16482.65                    GILEAD SCIENCES INC
# 1934883          2389.56                  ELI LILLY AND COMPANY
# 1934901          3638.26                    AYERST LABORATORIES
# 1934902          4041.05                         ASTRAZENECA LP
# 1934907          5677.65  RECKITT BENCKISER PHARMACEUTICALS INC
# 1934950          2675.18                 ALCON LABORATORIES INC
#
# [443702 rows x 5 columns]

# %%
scripts_by_comp = comp_scripts.groupby('company').agg({"total_drug_cost": np.sum})
top10 = scripts_by_comp.sort_values(['total_drug_cost'],ascending=False).round(decimals=2)
top10['total_drug_cost'] = top10.apply(lambda x: "{:,}".format(x['total_drug_cost']), axis=1)
top10['total_drug_cost'] = '$'+top10['total_drug_cost']
top10 = top10.reset_index().iloc[:10]

# %%
top10
# Out:
#                                 company  total_drug_cost
# 0                        ASTRAZENECA LP  $757,060,442.05
# 1                       GLAXOSMITHKLINE  $369,410,690.79
# 2                   GILEAD SCIENCES INC  $361,088,046.56
# 3                         MERCK  CO INC  $313,035,079.07
# 4  BOEHRINGER INGELHEIM PHARMACEUTICALS  $307,813,664.83
# 5                              NOVARTIS  $290,281,177.46
# 6                            PFIZER INC  $206,429,205.17
# 7               AVENTIS PHARMACEUTICALS  $203,123,038.16
# 8           JANSSEN PHARMACEUTICALS INC  $198,843,316.34
# 9               FOREST LABORATORIES INC  $186,255,882.94

# %% [markdown]
# # **<font color='Red'>Trying to link the unknowns</font>**

# %%
script_company_dict = pickle.load(open('script_company_dict.pkl', 'rb'))

# %%
scriptcomp_orig = pd.read_csv('/Volumes/Seagate/Galvanize/script_and_company.csv')

# %%
scriptcomp.head(2)
# Out:
#           drug_name  generic_name         company
# 0           ABILIFY             1  OTSUKA AMERICA
# 1  ABILIFY DISCMELT             1  OTSUKA AMERICA

# %%
#Only getting hte unkonwn ones
scriptcomp = scriptcomp[scriptcomp['company']=='UNKNOWN']

# %%
comps = pd.read_csv('/Volumes/Seagate/Galvanize/ndcxls/product.csv', usecols=[1,3,12])

# %%
print(len(comps))
comps.head()
# Out:
# 121214
#   PRODUCTNDC      PROPRIETARYNAME            LABELERNAME
# 0  0002-1200               Amyvid  Eli Lilly and Company
# 1  0002-1407  Quinidine Gluconate  Eli Lilly and Company
# 2  0002-1433            Trulicity  Eli Lilly and Company
# 3  0002-1434            Trulicity  Eli Lilly and Company
# 4  0002-1445                TALTZ  Eli Lilly and Company

# %%
#Removing excess spacing & any symbols
comps['PROPRIETARYNAME'] = [re.sub(r'[^\w\s]','',str(x).upper()) for x in comps['PROPRIETARYNAME']]
comps['PROPRIETARYNAME'] = comps['PROPRIETARYNAME'].str.strip()
comps['LABELERNAME'] = [re.sub(r'[^\w\s]','',str(x).upper()) for x in comps['LABELERNAME']]
comps['LABELERNAME'] = comps['LABELERNAME'].str.strip()

# %%
medsgrp = comps.groupby(['PROPRIETARYNAME','LABELERNAME'])['PRODUCTNDC'].nunique().to_frame().reset_index()

# %%
print(len(medsgrp))
medsgrp.head()
# Out:
# 69032
#                  PROPRIETARYNAME                LABELERNAME  PRODUCTNDC
# 0  01 MOISTURE FOUNDATION SPF 15  THE BODY SHOP WAKE FOREST           1
# 1  02 MOISTURE FOUNDATION SPF 15  THE BODY SHOP WAKE FOREST           1
# 2  03 MOISTURE FOUNDATION SPF 15  THE BODY SHOP WAKE FOREST           1
# 3  04 MOISTURE FOUNDATION SPF 15  THE BODY SHOP WAKE FOREST           1
# 4  05 MOISTURE FOUNDATION SPF 15  THE BODY SHOP WAKE FOREST           1

# %%
d = {}
def company_drug(x):
    if x['drug_name'] not in d:
        try:
            df = medsgrp[medsgrp['PROPRIETARYNAME'].str.contains \
                                        (x['drug_name'])].groupby('LABELERNAME')['PRODUCTNDC'].count()
            df = df.to_frame().reset_index().sort_values('PRODUCTNDC',ascending=False).reset_index().drop('index',axis=1)
            d[x['drug_name']] = df['LABELERNAME'][0]
        except IndexError:
            d[x['drug_name']] = np.nan

# %%
scriptcomp.apply(company_drug,axis=1)
# Out:
# 19      None
# 27      None
# 34      None
# 46      None
# 53      None
# 72      None
# 75      None
# 85      None
# 96      None
# 109     None
# 110     None
# 122     None
# 123     None
# 126     None
# 136     None
# 137     None
# 143     None
# 144     None
# 160     None
# 161     None
# 163     None
# 167     None
# 169     None
# 206     None
# 211     None
# 212     None
# 213     None
# 225     None
# 226     None
# 239     None
#         ...
# 1281    None
# 1282    None
# 1283    None
# 1284    None
# 1288    None
# 1289    None
# 1294    None
# 1295    None
# 1299    None
# 1303    None
# 1307    None
# 1308    None
# 1310    None
# 1325    None
# 1326    None
# 1327    None
# 1334    None
# 1335    None
# 1352    None
# 1354    None
# 1355    None
# 1356    None
# 1357    None
# 1360    None
# 1361    None
# 1372    None
# 1385    None
# 1426    None
# 1432    None
# 1433    None
# Length: 235, dtype: object

# %%
#Compiling the dictionary
comp_dict = {**script_company_dict, **d}

# %%
d['ADACEL TDAP'] = 'SANOFI PASTEUR INC'

# %%
#Add newly linked company names to the df
scriptcomp["company"] = scriptcomp["drug_name"].map(d)

# %%
scriptcomp.head()
# Out:
#                drug_name  generic_name             company
# 19           ADACEL TDAP             1  SANOFI PASTEUR INC
# 27  ADVOCATE PEN NEEDLES             1                 NaN
# 34           AK POLY BAC             1                 NaN
# 46        ALPRAZOLAM ODT             1                 NaN
# 53               ALZ NAC             1                 NaN

# %%
left = scriptcomp[pd.isnull(scriptcomp['company'])]
len(left),len(scriptcomp_orig)
# Out:
# (190, 1448)

# %%
pickle.dump(comp_dict, open('script_company_dict.pkl', 'wb'))

# %% [markdown]
# ## Linking to the OG scripts dataframe

# %%
scripts = pd.read_csv('/volumes/Seagate/Galvanize/nj_scripts_all_years.csv')

# %%
scripts.head(2)
# Out:
#           npi       ln       fn     city state specialty_description  year  \
# 0  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
# 1  1528036670  LANTERI  VINCENT  MAYWOOD    NJ               Urology  2013
#
#    recieved_payments  total_claim_count  amount_brand  \
# 0               True                 48            48
# 1               True                 16             0
#
#                     drug_name                generic_name  brand_drug?  \
# 0                      VIAGRA                  SILDENAFIL         True
# 1  CLOTRIMAZOLE BETAMETHASONE  CLOTRIMAZOLE BETAMETHASONE        False
#
#    total_day_supply  total_drug_cost
# 0              1481          8957.33
# 1               367           806.59

# %%
#Add newly linked company names to the df
scripts["drug_company"] = scripts["drug_name"].map(comp_dict)

# %%
#Writing unknown where I couln't link the company, and generic for the company
dic = {}
def unknown_and_generic(x):
    if (x['drug_name'] == x['generic_name']):
            dic[x['drug_name']] = 'GENERIC'
    elif (x['drug_name'] != x['generic_name']) and (x['drug_name'] not in dic):
        dic[x['drug_name']] = 'UNKNOWN'

# %%
scriptsgrp = scripts[pd.isnull(scripts['drug_company'])]
scriptsgrp = scriptsgrp.groupby(['drug_name','generic_name'])['npi'].count().to_frame().reset_index()

# %%
scriptsgrp.apply(unknown_and_generic,axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 924    None
# 925    None
# 926    None
# 927    None
# 928    None
# 929    None
# 930    None
# 931    None
# 932    None
# 933    None
# 934    None
# 935    None
# 936    None
# 937    None
# 938    None
# 939    None
# 940    None
# 941    None
# 942    None
# 943    None
# 944    None
# 945    None
# 946    None
# 947    None
# 948    None
# 949    None
# 950    None
# 951    None
# 952    None
# 953    None
# Length: 954, dtype: object

# %%
#Add newly linked company names to the df
drug_comp = {**comp_dict, **dic}
scripts["drug_company"] = scripts["drug_name"].map(drug_comp)

# %%
scripts
# Out:
#                 npi           ln         fn                 city state  \
# 0        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 1        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 2        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 3        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 4        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 5        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 6        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 7        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 8        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 9        1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 10       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 11       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 12       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 13       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 14       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 15       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 16       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 17       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 18       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 19       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 20       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 21       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 22       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 23       1528036670      LANTERI    VINCENT              MAYWOOD    NJ
# 24       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# 25       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# 26       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# 27       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# 28       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# 29       1699730937     SAUNDERS       ERIC            RIDGEWOOD    NJ
# ...             ...          ...        ...                  ...   ...
# 1934984  1013158443        GREEN      ELISA             DENVILLE    NJ
# 1934985  1316283708        ROSIN       DALE           SOMERVILLE    NJ
# 1934986  1548318694    LIPSHULTZ    RICHARD            CRESSKILL    NJ
# 1934987  1619293644         PANE    ANTHONY             ROCKAWAY    NJ
# 1934988  1124040407       SHKLAR      DAVID               CAMDEN    NJ
# 1934989  1528136595         GORO      BERIT           SAYREVILLE    NJ
# 1934990  1396172797       CARUSO      KELLY           BURLINGTON    NJ
# 1934991  1396172797       CARUSO      KELLY           BURLINGTON    NJ
# 1934992  1730287103      SAMANEZ      JORGE             PATERSON    NJ
# 1934993  1306973987      MIGLANI    SHEFALI           MONROE TWP    NJ
# 1934994  1194825463    LUSTBADER     STEVEN           OLD BRIDGE    NJ
# 1934995  1598871162       TUCKER   BRADFORD  EGG HARBOR TOWNSHIP    NJ
# 1934996  1568507317    KAMIENSKI       MARY               NEWARK    NJ
# 1934997  1336335033       LIEBES      DAVID           LIVINGSTON    NJ
# 1934998  1992935100    STATHAKES    LARISSA              TRENTON    NJ
# 1934999  1457377699        ESKIN     BARNET          JERSEY CITY    NJ
# 1935000  1942382148       BELOFF   MICHELLE            FAIR LAWN    NJ
# 1935001  1629147624    POPLAWSKI       MARK           TOMS RIVER    NJ
# 1935002  1376647735       DAWSON  JACQUELYN            GLEN ROCK    NJ
# 1935003  1114265642        ARAUZ    JESSICA          JERSEY CITY    NJ
# 1935004  1609814870  FRIEDENTHAL        ROY            HAMMONTON    NJ
# 1935005  1497811228       POGODA       JOHN           WOODBRIDGE    NJ
# 1935006  1902117773       CHACKO    ABRAHAM            STRATFORD    NJ
# 1935007  1518920768     CHAIKLIN     RONALD               KEARNY    NJ
# 1935008  1982782561       LAWSON    STEPHEN               EDISON    NJ
# 1935009  1518951458        SANTO    MICHAEL             RED BANK    NJ
# 1935010  1649335902        VIDAL    LILLIAN            ENGLEWOOD    NJ
# 1935011  1013034982          SEU     SILVIA         ROSELLE PARK    NJ
# 1935012  1083711469        STEIN       IVAN          WEST ORANGE    NJ
# 1935013  1982689352         SAFT     STEVEN          CHERRY HILL    NJ
#
#                                      specialty_description  year  \
# 0                                                  Urology  2013
# 1                                                  Urology  2013
# 2                                                  Urology  2013
# 3                                                  Urology  2013
# 4                                                  Urology  2013
# 5                                                  Urology  2013
# 6                                                  Urology  2013
# 7                                                  Urology  2013
# 8                                                  Urology  2013
# 9                                                  Urology  2013
# 10                                                 Urology  2013
# 11                                                 Urology  2013
# 12                                                 Urology  2013
# 13                                                 Urology  2013
# 14                                                 Urology  2013
# 15                                                 Urology  2013
# 16                                                 Urology  2013
# 17                                                 Urology  2013
# 18                                                 Urology  2013
# 19                                                 Urology  2013
# 20                                                 Urology  2013
# 21                                                 Urology  2013
# 22                                                 Urology  2013
# 23                                                 Urology  2013
# 24                                           Ophthalmology  2013
# 25                                           Ophthalmology  2013
# 26                                           Ophthalmology  2013
# 27                                           Ophthalmology  2013
# 28                                           Ophthalmology  2013
# 29                                           Ophthalmology  2013
# ...                                                    ...   ...
# 1934984                                 Nurse Practitioner  2015
# 1934985                                         Psychiatry  2015
# 1934986                                            Dentist  2015
# 1934987                              Obstetrics/Gynecology  2015
# 1934988                                  Internal Medicine  2015
# 1934989                                          Optometry  2015
# 1934990                                 Nurse Practitioner  2015
# 1934991                                 Nurse Practitioner  2015
# 1934992                                            Dentist  2015
# 1934993                                          Optometry  2015
# 1934994                                            Dentist  2015
# 1934995                                 Orthopedic Surgery  2015
# 1934996                                 Nurse Practitioner  2015
# 1934997                                            Dentist  2015
# 1934998                                Physician Assistant  2015
# 1934999                                 Emergency Medicine  2015
# 1935000                              Obstetrics/Gynecology  2015
# 1935001                                           Podiatry  2015
# 1935002                                            Dentist  2015
# 1935003                                 Nurse Practitioner  2015
# 1935004                                 Orthopedic Surgery  2015
# 1935005                                            Dentist  2015
# 1935006  Student in an Organized Health Care Education/...  2015
# 1935007                                            Dentist  2015
# 1935008                                            Dentist  2015
# 1935009                                            Dentist  2015
# 1935010                                            Dentist  2015
# 1935011                                            Dentist  2015
# 1935012                       Oral Surgery (dentists only)  2015
# 1935013                                           Podiatry  2015
#
#          recieved_payments  total_claim_count  amount_brand  \
# 0                     True                 48            48
# 1                     True                 16             0
# 2                     True                 27             0
# 3                     True                 34             0
# 4                     True                 29            29
# 5                     True                 28             0
# 6                     True                 35             0
# 7                     True                 37            37
# 8                     True                 15             0
# 9                     True                111             0
# 10                    True                 14             0
# 11                    True                 26            26
# 12                    True                 23            23
# 13                    True                 14             0
# 14                    True                 38             0
# 15                    True                 16            16
# 16                    True                193             0
# 17                    True                 17             0
# 18                    True                578             0
# 19                    True                 40            40
# 20                    True                 19            19
# 21                    True                 54             0
# 22                    True                 28             0
# 23                    True                 97             0
# 24                    True                 94             0
# 25                    True                 13            13
# 26                    True                 41            41
# 27                    True                 22            22
# 28                    True                 20             0
# 29                    True                 11             0
# ...                    ...                ...           ...
# 1934984              False                 14             0
# 1934985              False                 12             0
# 1934986               True                 23             0
# 1934987              False                 11             0
# 1934988               True                 16             0
# 1934989              False                 13             0
# 1934990              False                 14             0
# 1934991              False                 12             0
# 1934992              False                 11             0
# 1934993              False                 16             0
# 1934994              False                 40             0
# 1934995               True                 11             0
# 1934996              False                 12             0
# 1934997               True                 32             0
# 1934998              False                 11             0
# 1934999               True                 26             0
# 1935000               True                 11             0
# 1935001               True                 17             0
# 1935002              False                 16             0
# 1935003              False                 12             0
# 1935004              False                 11             0
# 1935005              False                 19             0
# 1935006              False                 20             0
# 1935007              False                 22             0
# 1935008               True                 19             0
# 1935009              False                 19             0
# 1935010               True                 19             0
# 1935011              False                 42             0
# 1935012               True                 22             0
# 1935013              False                 11             0
#
#                               drug_name                    generic_name  \
# 0                                VIAGRA                      SILDENAFIL
# 1            CLOTRIMAZOLE BETAMETHASONE      CLOTRIMAZOLE BETAMETHASONE
# 2                            IMIPRAMINE                      IMIPRAMINE
# 3                        NITROFURANTOIN                  NITROFURANTOIN
# 4                              ANDROGEL                    TESTOSTERONE
# 5                 ACETAMINOPHEN CODEINE           ACETAMINOPHEN CODEINE
# 6                   OXYBUTYNIN CHLORIDE             OXYBUTYNIN CHLORIDE
# 7                              VESICARE           SOLIFENACIN SUCCINATE
# 8                           AMOXICILLIN                     AMOXICILLIN
# 9                         CIPROFLOXACIN                   CIPROFLOXACIN
# 10                          ALLOPURINOL                     ALLOPURINOL
# 11                               CIALIS                       TADALAFIL
# 12                               FLOMAX                      TAMSULOSIN
# 13                  OXYBUTYNIN CHLORIDE             OXYBUTYNIN CHLORIDE
# 14        SULFAMETHOXAZOLE TRIMETHOPRIM   SULFAMETHOXAZOLE TRIMETHOPRIM
# 15                              RAPAFLO                       SILODOSIN
# 16                          FINASTERIDE                     FINASTERIDE
# 17                       NITROFURANTOIN                  NITROFURANTOIN
# 18                           TAMSULOSIN                      TAMSULOSIN
# 19                              AVODART                     DUTASTERIDE
# 20                               TOVIAZ           FESOTERODINE FUMARATE
# 21                         BICALUTAMIDE                    BICALUTAMIDE
# 22                            TERAZOSIN                       TERAZOSIN
# 23                            ALFUZOSIN                       ALFUZOSIN
# 24                          LATANOPROST                     LATANOPROST
# 25                              VIGAMOX                    MOXIFLOXACIN
# 26                              LUMIGAN                     BIMATOPROST
# 27                           TRAVATAN Z                      TRAVOPROST
# 28                 PREDNISOLONE ACETATE            PREDNISOLONE ACETATE
# 29             TOBRAMYCIN DEXAMETHASONE        TOBRAMYCIN DEXAMETHASONE
# ...                                 ...                             ...
# 1934984            LEVOTHYROXINE SODIUM            LEVOTHYROXINE SODIUM
# 1934985                    BUPROPION SR                    BUPROPION SR
# 1934986                     AMOXICILLIN                     AMOXICILLIN
# 1934987                      RALOXIFENE                      RALOXIFENE
# 1934988                    LEVOFLOXACIN                    LEVOFLOXACIN
# 1934989                     LATANOPROST                     LATANOPROST
# 1934990             ALPRAZOLAM INTENSOL             ALPRAZOLAM INTENSOL
# 1934991         OXYCODONE ACETAMINOPHEN         OXYCODONE ACETAMINOPHEN
# 1934992                     AMOXICILLIN                     AMOXICILLIN
# 1934993                 FLUOROMETHOLONE                 FLUOROMETHOLONE
# 1934994                     AMOXICILLIN                     AMOXICILLIN
# 1934995                       CELECOXIB                       CELECOXIB
# 1934996  LISINOPRIL HYDROCHLOROTHIAZIDE  LISINOPRIL HYDROCHLOROTHIAZIDE
# 1934997                     AMOXICILLIN                     AMOXICILLIN
# 1934998                 CYCLOBENZAPRINE                 CYCLOBENZAPRINE
# 1934999         OXYCODONE ACETAMINOPHEN         OXYCODONE ACETAMINOPHEN
# 1935000                      RALOXIFENE                      RALOXIFENE
# 1935001                       IBUPROFEN                       IBUPROFEN
# 1935002                     AMOXICILLIN                     AMOXICILLIN
# 1935003                        NAPROXEN                        NAPROXEN
# 1935004                       IBUPROFEN                       IBUPROFEN
# 1935005                     AMOXICILLIN                     AMOXICILLIN
# 1935006             PANTOPRAZOLE SODIUM             PANTOPRAZOLE SODIUM
# 1935007         CHLORHEXIDINE GLUCONATE         CHLORHEXIDINE GLUCONATE
# 1935008                     AMOXICILLIN                     AMOXICILLIN
# 1935009                     AMOXICILLIN                     AMOXICILLIN
# 1935010                     AMOXICILLIN                     AMOXICILLIN
# 1935011                     AMOXICILLIN                     AMOXICILLIN
# 1935012                     AMOXICILLIN                     AMOXICILLIN
# 1935013                      GABAPENTIN                      GABAPENTIN
#
#          brand_drug?  total_day_supply  total_drug_cost  \
# 0               True              1481          8957.33
# 1              False               367           806.59
# 2              False              1380           519.91
# 3              False              1480          1502.16
# 4               True              1236         17234.63
# 5              False               106           119.43
# 6              False              2070           667.09
# 7               True              2145         13580.78
# 8              False               124            70.21
# 9              False               889           645.97
# 10             False              1260           146.39
# 11              True               397          3348.48
# 12              True               990          5060.75
# 13             False              1200          1791.67
# 14             False               319           215.21
# 15              True               940          4242.73
# 16             False             13890          6517.24
# 17             False               260           991.53
# 18             False             41527         16615.95
# 19              True              1560          6418.34
# 20              True              1410          7328.35
# 21             False              3540          3849.68
# 22             False              1920           576.58
# 23             False              6957          9164.19
# 24             False              3622          2147.15
# 25              True               143          1320.04
# 26              True              1419          5446.44
# 27              True               838          3366.02
# 28             False               496           405.98
# 29             False               174          1002.21
# ...              ...               ...              ...
# 1934984        False               815           322.75
# 1934985        False               360           119.17
# 1934986        False               188            99.66
# 1934987        False               330          1041.77
# 1934988        False                80           181.10
# 1934989        False               738           186.43
# 1934990        False               345            83.72
# 1934991        False                97           151.55
# 1934992        False                85            54.73
# 1934993        False               361          1250.80
# 1934994        False               339           167.67
# 1934995        False               450          1588.63
# 1934996        False               525            46.44
# 1934997        False               161           112.77
# 1934998        False                47            42.20
# 1934999        False                69           145.34
# 1935000        False               630          2722.85
# 1935001        False               230            68.91
# 1935002        False                76            31.56
# 1935003        False               187            51.79
# 1935004        False               330            66.14
# 1935005        False               145            83.60
# 1935006        False               780           163.78
# 1935007        False               533           119.32
# 1935008        False               134            61.10
# 1935009        False                89            64.55
# 1935010        False                79            45.56
# 1935011        False               212           164.86
# 1935012        False               135            94.23
# 1935013        False               330            60.28
#
#                                  drug_company
# 0                                  PFIZER INC
# 1                                     GENERIC
# 2                                     GENERIC
# 3                                     GENERIC
# 4                                  ABBVIE INC
# 5                                     GENERIC
# 6                                     GENERIC
# 7                                    ASTELLAS
# 8                                     GENERIC
# 9                                     GENERIC
# 10                                    GENERIC
# 11                      ELI LILLY AND COMPANY
# 12       BOEHRINGER INGELHEIM PHARMACEUTICALS
# 13                                    GENERIC
# 14                                    GENERIC
# 15                          WATSON PHARMA INC
# 16                                    GENERIC
# 17                                    GENERIC
# 18                                    GENERIC
# 19                            GLAXOSMITHKLINE
# 20                                 PFIZER INC
# 21                                    GENERIC
# 22                                    GENERIC
# 23                                    GENERIC
# 24                                    GENERIC
# 25                     ALCON LABORATORIES INC
# 26                               ALLERGAN INC
# 27                     ALCON LABORATORIES INC
# 28                                    GENERIC
# 29                                    GENERIC
# ...                                       ...
# 1934984                               GENERIC
# 1934985                               GENERIC
# 1934986                               GENERIC
# 1934987                               GENERIC
# 1934988                               GENERIC
# 1934989                               GENERIC
# 1934990                               GENERIC
# 1934991                               GENERIC
# 1934992                               GENERIC
# 1934993                               GENERIC
# 1934994                               GENERIC
# 1934995                               GENERIC
# 1934996                               GENERIC
# 1934997                               GENERIC
# 1934998                               GENERIC
# 1934999                               GENERIC
# 1935000                               GENERIC
# 1935001                               GENERIC
# 1935002                               GENERIC
# 1935003                               GENERIC
# 1935004                               GENERIC
# 1935005                               GENERIC
# 1935006                               GENERIC
# 1935007                               GENERIC
# 1935008                               GENERIC
# 1935009                               GENERIC
# 1935010                               GENERIC
# 1935011                               GENERIC
# 1935012                               GENERIC
# 1935013                               GENERIC
#
# [1935014 rows x 16 columns]

# %%
scripts.to_csv('/volumes/Seagate/Galvanize/nj_scripts_all_years.csv',index=False)

# %%
pickle.dump(drug_comp, open('script_company_dict.pkl', 'wb'))

# %%
def clean_drug_name(df,wrong_name, right_name):
    """
    Input:
        df: df, dataframe to be used
        wrong_name: Str, wrong name that is listed in df
        right_name: Str, right name to be changed to
    Output:
        None
    """
    #Getting all the locations where it says the wrong name
    for col in ['drug_name']:
        l = list(df[(df['drug_name']==wrong_name)&(df['generic_name']==right_name)].index.values)
        for i in l:
            df.at[i,'drug_name'] = right_name

# %%
clean_drug_name(scripts,'ALPRAZOLAM ODT','ALPRAZOLAM INTENSOL')

# %%
l = list(scripts[(scripts['drug_name']=='ALPRAZOLAM INTENSOL')&(scripts['generic_name']=='ALPRAZOLAM INTENSOL')].index.values)

# %%
scripts['drug_company'] = scripts['drug_company'].map(lambda x: ' '.join((str(x).replace('INCORPORATED','').replace('CORPORATION','')\
                                    .replace('INC','').replace('CORP','').replace('LLC','').replace('LP','')).split()))

# %%
pd.options.display.max_rows = 60

# %%
def clean_company_name(df,wrong_name, right_name):
    """
    Input:
        df: df, dataframe to be used
        wrong_name: Str, wrong name that is listed in df
        right_name: Str, right name to be changed to
    Output:
        None
    """
    #Getting all the locations where it says the wrong name
    l = list(df[df['drug_company']==wrong_name].index.values)
    #Replacing all the "ZOLL SERVICES AKA ZOLL LIFECOR" with "ZOLL LIFECOR"
    for i in l:
        df.at[i,'drug_company'] = right_name

# %%
clean_company_name(scripts,'WYETH LABORATORIES','PFIZER')
clean_company_name(scripts,'WYETH PHARMACEUTICALS A SUBSIDIARY OF PFIZER','PFIZER')

# %%
pd.DataFrame(scripts['drug_company'].unique()).sort_values(by=0)
# Out:
#                                          0
# 204                3M ESPE DENTAL PRODUCTS
# 16                     ABBOTT LABORATORIES
# 2                                   ABBVIE
# 206                     ABRAXIS BIOSCIENCE
# 169                 ACELLA PHARMACEUTICALS
# 109                    ACORDA THERAPEUTICS
# 38                                 ACTAVIS
# 138            ACTELION PHARMACEUTICALS US
# 170                ACTIENT PHARMACEUTICALS
# 247                  ACTON PHARMACEUTICALS
# 220               AEGERION PHARMACEUTICALS
# 182             AFFORDABLE PHARMACEUTICALS
# 140                                  AKORN
# 106                AKRIMAX PHARMACEUTICALS
# 130                  ALAVEN PHARMACEUTICAL
# 8                       ALCON LABORATORIES
# 228                ALEXION PHARMACEUTICALS
# 185                               ALKERMES
# 9                                 ALLERGAN
# 99                         ALLISON MEDICAL
# 90                         ALMATICA PHARMA
# 82      AMARIN PHARMACEUTICALS IRELAND LTD
# 167                 AMEDRA PHARMACEUTICALS
# 77               AMERICAN HEALTH PACKAGING
# 208                        AMERICAN REGENT
# 235                     AMERISOURCE BERGEN
# 46                               AMGEN USA
# 89                            AMGENIMMUNEX
# 92                  AMNEAL PHARMACEUTICALS
# 240                 ANACOR PHARMACEUTICALS
# ..                                     ...
# 246            TAIHO PHARMACEUTICAL CO LTD
# 21          TAKEDA PHARMACEUTICALS AMERICA
# 231               TARO PHARMACEUTICALS USA
# 20                    TEVA PHARMACEUTICALS
# 202                  THE MEDICINES COMPANY
# 177     THE PROCTER GAMBLE DISTRIBUTING CO
# 52                     TRIGEN LABORATORIES
# 93                              UCB PHARMA
# 146                    UNITED THERAPEUTICS
# 22                                 UNKNOWN
# 50                UPSHERSMITH LABORATORIES
# 200                           US WORLDMEDS
# 80   VALEANT PHARMACEUTICALS NORTH AMERICA
# 124                VALIDUS PHARMACEUTICALS
# 238                  VANDA PHARMACEUTICALS
# 171                          VANSEN PHARMA
# 215                 VERTEX PHARMACEUTICALS
# 121               VERTICAL PHARMACEUTICALS
# 97                         VIIV HEALTHCARE
# 145                VISTAKON PHARMACEUTICAL
# 163                                  VIVUS
# 28            WARNER CHILCOTT LABORATORIES
# 6                            WATSON PHARMA
# 19                 WESTWARD PHARMACEUTICAL
# 198          WOMENS CHOICE PHARMACEUTICALS
# 96                                XENOPORT
# 178                   XGEN PHARMACEUTICALS
# 158                                    YTE
# 242                                ZOGENIX
# 100              ZYDUS PHARMACEUTICALS USA
#
# [250 rows x 1 columns]

# %%
clean_company_name(scripts,'ACTAVIS KADIAN','ACTAVIS')
clean_company_name(scripts,'ACTAVIS PHARMA','ACTAVIS')
clean_company_name(scripts,'ARBOR PHARMACEUTICALS IRELAND LIMITED','ARBOR PHARMACEUTICALS')
clean_company_name(scripts,'ASTELLAS PHARMA US','ASTELLAS')
clean_company_name(scripts,'BRISTOLMYERS SQUIBB AND GILEAD SCIENCE','GILEAD SCIENCES')
clean_company_name(scripts,'BRISTOLMYERS SQUIBB COMPANY','BRISTOLMYERS SQUIBB')
clean_company_name(scripts,'BRISTOLMYERS SQUIBBSANOFI PARTNERSHIP','BRISTOLMYERS SQUIBB')
clean_company_name(scripts,'BRISTOLMYERS SQUIBB PHARMA CO','BRISTOLMYERS SQUIBB')
clean_company_name(scripts,'COVIS PHARMA SARL','COVIS PHARMACEUTICALS')
clean_company_name(scripts,'CSL BEHRING GMBH','CSL BEHRING')
clean_company_name(scripts,'GLAXOSMITHKLINE BIOLOGICALS SA','GLAXOSMITHKLINE')
clean_company_name(scripts,'GSK CONSUMER HEALTHCARE','GSK CONSUMER HEALTH')
clean_company_name(scripts,'IMPAX SPECIALTY PHARMA','IMPAX LABORATORIES')
clean_company_name(scripts,'JANSSEN BIOTECH','JANSSEN PHARMACEUTICALS')
clean_company_name(scripts,'JANSSEN PRODUCTS','JANSSEN PHARMACEUTICALS')
clean_company_name(scripts,'JAZZ PHARMACEUTICALS COMMERCIAL','JAZZ PHARMACEUTICALS')
clean_company_name(scripts,'KREMERS URBAN','KREMERS URBAN PHARMACEUTICALS')
clean_company_name(scripts,'MALLKRODT BRAND PHARMACEUTICALS','MALLKRODT PHARMACEUTICALS')
clean_company_name(scripts,'MALLKRODT','MALLKRODT PHARMACEUTICALS')
clean_company_name(scripts,'MERCK SHARP DOHME','MERCK')
clean_company_name(scripts,'MERCKSCHERINGPLOUGH JV','MERCK')
clean_company_name(scripts,'MYLAN INSTITUTIONAL','MYLAN PHARMACEUTICALS')
clean_company_name(scripts,'MYLAN SPECIALTY','MYLAN PHARMACEUTICALS')
clean_company_name(scripts,'PAR PHARMACEUTICAL','PAR PHARMACEUTICALS')
clean_company_name(scripts,'SCHERING HEALTHCARE PRODUCTS','SCHERING')
clean_company_name(scripts,'TEVA GLOBAL RESPIRATORY RESEARCH','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'TEVA NEUROSCIENCE','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'TEVA PARENTERAL MEDICINES','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'TEVA PHARMACEUTICALS USA','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'TEVA RESPIRATORY','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'TEVA WOMENS HEALTH','TEVA PHARMACEUTICALS')
clean_company_name(scripts,'UCB','UCB PHARMA')
clean_company_name(scripts,'UCB MANUFACTURING','UCB PHARMA')

# %%
x = ayments_nj_full.company.unique()

# %%
sorted(x)
# Out:
# ['180 MEDICAL',
#  '3M COMPANY',
#  'AASTROM BIOSCIENCES',
#  'ABB CONCISE OPTICAL GROUP',
#  'ABBOTT LABORATORIES',
#  'ABBVIE',
#  'ABIOMED',
#  'ACCESS CLOSURE',
#  'ACCLARENT',
#  'ACCURAY',
#  'ACE SURGICAL SUPPLY CO',
#  'ACELL',
#  'ACIST MEDICAL SYSTEMS',
#  'ACORDA THERAPEUTICS',
#  'ACTAVIS PHARMA',
#  'ACTELION CLINICAL RESEARCH',
#  'ACTELION PHARMACEUTICALS LTD',
#  'ACTELION PHARMACEUTICALS US',
#  'ACUMED',
#  'ADEC',
#  'ADVANCED MEDICAL PARTNERS',
#  'ADVANCED ORTHOPAEDIC SOLUTIONS',
#  'ADVANCED RESPIRATORY',
#  'ADVANDX',
#  'AEGERION PHARMACEUTICALS',
#  'AEROCRINE',
#  'AESCULAP',
#  'AESCULAP BIOLOGICS',
#  'AESCULAP IMPLANT SYSTEMS',
#  'AHATEC SPINE',
#  'AKORN',
#  'AKRIMAX PHARMACEUTICALS',
#  'ALCON LABORATORIES',
#  'ALCON RESEARCH LTD',
#  'ALEXION PHARMACEUTICALS',
#  'ALGETA US',
#  'ALIGN TECHNOLOGY',
#  'ALIMERA SCIENCES',
#  'ALKABELLO',
#  'ALKERMES',
#  'ALLERGAN',
#  'ALLIQUA BIOMEDICAL',
#  'ALMATICA PHARMA',
#  'ALTATEC GMBH',
#  'ALTUS PARTNERS',
#  'AMAG PHARMACEUTICALS',
#  'AMARIN PHARMA',
#  'AMD GROUP',
#  'AMD LASERS',
#  'AMENDIA',
#  'AMERICAN MEDICAL SYSTEMS',
#  'AMGEN',
#  'AMNEAL PHARMACEUTICALS',
#  'AMNIOX MEDICAL',
#  'ANACOR PHARMACEUTICALS',
#  'ANALOGIC',
#  'ANGIODYNAMICS',
#  'ANGIOSCORE',
#  'ANIMAS',
#  'ANTARES PHARMA',
#  'APOLLO ENDOSURGERY',
#  'APPLIED MEDICAL RESOURCES',
#  'APTALIS PHARMA US',
#  'APTUS ENDOSYSTEMS',
#  'AQUA PHARMACEUTICALS',
#  'ARBOR PHARMACEUTICALS',
#  'ARGON MEDICAL DEVICES',
#  'ARIAD PHARMACEUTICALS',
#  'ARIOSA DIAGNOSTICS',
#  'ARROW INTERNATIONAL',
#  'ARTHREX',
#  'ARTHROCARE',
#  'ARTHROSURFACE',
#  'ASCEND THERAPEUTICS US',
#  'ASCENSION ORTHOPEDICS',
#  'ASD SPECIALTY HEALTHCARE',
#  'ASTELLAS PHARMA EUROPE BV',
#  'ASTELLAS PHARMA GLOBAL DEVELOPMENT',
#  'ASTELLAS PHARMA US',
#  'ASTELLAS SCIENTIFIC AND MEDICAL AFFAIRS',
#  'ASTORA WOMENS HEALTH',
#  'ASTRAZENECA AB',
#  'ASTRAZENECA PHARMACEUTICALS',
#  'ASTRAZENECA UK LIMITED',
#  'ASTUTE MEDICAL',
#  'ASURAGEN',
#  'ATLAS SPINE',
#  'ATRICURE',
#  'ATRIUM MEDICAL',
#  'AUGMENIX',
#  'AUXILIUM PHARMACEUTICALS',
#  'AVANIR PHARMACEUTICALS',
#  'AVID RADIOPHARMACEUTICALS',
#  'AVINGER',
#  'AVION PHARMACEUTICALS',
#  'AXOGEN',
#  'B BRAUN MEDICAL',
#  'BACTERIN INTERNATIONAL',
#  'BANYAN INTERNATIONAL',
#  'BARD ACCESS SYSTEMS',
#  'BARD PERIPHERAL VASCULAR',
#  'BAUSCH AND LOMB',
#  'BAXALTA US',
#  'BAXANO SURGICAL',
#  'BAXTER HEALTHCARE',
#  'BAYER HEALTHCARE',
#  'BAYER HEALTHCARE PHARMACEUTICALS',
#  'BEAVERVISITEC INTERNATIONAL',
#  'BECTON DICKINSON AND COMPANY',
#  'BENCO DENTAL SUPPLY CO',
#  'BG MEDICINE',
#  'BIO PRODUCTS LABORATORY',
#  'BIOCOMPATIBLES',
#  'BIOCOMPOSITES',
#  'BIODELIVERY SCIENCES INTERNATIONAL',
#  'BIOFIRE DIAGNOSTICS',
#  'BIOGEN',
#  'BIOHORIZONS IMPLANT SYSTEMS',
#  'BIOLASE',
#  'BIOMARIN PHARMACEUTICAL',
#  'BIOMEDICAL ENTERPRISES',
#  'BIOMET 3I',
#  'BIOMET 3I MEXICO SA DE CV',
#  'BIOMET BIOLOGICS',
#  'BIOMET EUROPE LTD',
#  'BIOMET MICROFIXATION',
#  'BIOMET ORTHOPEDICS',
#  'BIOMET SPINE',
#  'BIOMET SPORTS MEDICINE',
#  'BIOMET TRAUMA',
#  'BIOMIMETIC THERAPEUTICS',
#  'BIORAD LABORATORIES',
#  'BIOSENSE WEBSTER',
#  'BIOTRONIK',
#  'BIOVENTUS',
#  'BISCO',
#  'BLOCKADE MEDICAL',
#  'BLUE BELT TECHNOLOGIES',
#  'BOEHRINGER INGELHEIM PHARMACEUTICALS',
#  'BOLTON MEDICAL',
#  'BOSTON SCIENTIFIC',
#  'BOVIE MEDICAL',
#  'BRAEMAR MANUFACTURING',
#  'BRAINLAB',
#  'BRAINTREE LABORATORIES',
#  'BTG INTERNATIONAL',
#  'C R BARD SUBSIDIARIES',
#  'CADENCE PHARMACEUTICALS',
#  'CALDERA MEDICAL',
#  'CAPNIA',
#  'CAPTIVA SPINE',
#  'CARDIAC ASSIST',
#  'CARDICA',
#  'CARDINAL HEALTH 108',
#  'CARDINAL HEALTH 110',
#  'CARDINAL HEALTH 200',
#  'CARDINAL HEALTH PR 120',
#  'CARDIOVASCULAR SYSTEMS',
#  'CARDIVA MEDICAL',
#  'CAREFUSION',
#  'CARESTREAM DENTAL',
#  'CARL ZEISS MEDITEC',
#  'CATHETER ROBOTICS',
#  'CAYENNE MEDICAL',
#  'CELGENE',
#  'CELLERATION_',
#  'CELONOVA BIOSCIENCES',
#  'CENTINEL SPINE',
#  'CENTRIX',
#  'CHIESI USA',
#  'CHOICE SPINE',
#  'CIANNA MEDICAL',
#  'CIPHER PHARMACEUTICALS US',
#  'CLARITY MEDICAL SYSTEM',
#  'CLINICIANS CHOICE DENTAL PRODUCTS',
#  'COCHLEAR AMERICAS',
#  'COGENTIX MEDICAL',
#  'COLLAGEN MATRIX',
#  'COLOPLAST',
#  'COLTENE WHALEDENT',
#  'COMSORT',
#  'CONFORMIS',
#  'CONMED',
#  'CONSENSUS ORTHOPEDICS',
#  'CONVATEC',
#  'CONVENTUS ORTHOPAEDICS',
#  'CONVERGENT DENTAL',
#  'COOK',
#  'COOK BIOTECH',
#  'COOK MEDICAL',
#  'COOK RESEARCH',
#  'COOPERSURGICAL',
#  'COOPERVISION',
#  'CORCEPT THERAPEUTICS',
#  'CORDIS',
#  'CORELINK',
#  'CORINDUS',
#  'CORMATRIX CARDIOVASCULAR',
#  'COVIDIEN',
#  'COVIDIEN SALES',
#  'COVIS PHARMACEUTICALS',
#  'CRANIAL TECHNOLOGIES',
#  'CRYO SPECIALTY MEDICAL',
#  'CRYOLIFE',
#  'CSL BEHRING',
#  'CUBIST PHARMACEUTICALS',
#  'CUMBERLAND PHARMACEUTICALS',
#  'CVRX',
#  'CYBERONICS',
#  'CYNOSURE',
#  'D4D TECHNOLOGIES',
#  'DAIICHI SANKYO',
#  'DARA BIOSCIENCES',
#  'DASH MEDICAL GLOVES',
#  'DATASCOPE',
#  'DAVOL',
#  'DELTEX MEDICAL SC',
#  'DENDREON',
#  'DENMAT HOLDINGS',
#  'DENTAL EQUIPMENT',
#  'DENTAL HEALTH PRODUCTS',
#  'DENTAL IMAGING TECHNOLOGIES',
#  'DENTALEZ',
#  'DENTIUM CO LTD',
#  'DENTIUM USA',
#  'DENTSPLY',
#  'DENTSPLY IH',
#  'DENTSPLY INTERNATIONAL',
#  'DENTSPLY NZ LIMITED',
#  'DEPOMED',
#  'DEPUY ORTHOPAEDICS',
#  'DEPUY SYNTHES PRODUCTS',
#  'DEPUY SYNTHES SALES',
#  'DERMA SCIENCES',
#  'DEVICOR MEDICAL PRODUCTS',
#  'DEXCEL PHARMA TECHNOLOGIES LTD',
#  'DEXCOM',
#  'DFINE',
#  'DIADEXUS',
#  'DIGESTIVE CARE',
#  'DIGIRAD',
#  'DISCOVERY LABORATORIES',
#  'DJO',
#  'DMG AMERICA',
#  'DORNIER MEDTECH AMERICA',
#  'DOXA DENTAL',
#  'DRREDDYS LABORATORIES',
#  'DS HEALTHCARE',
#  'DUCHESNAY USA',
#  'DUNE MEDICAL DEVICES',
#  'DURATA THERAPEUTICS',
#  'DUSA PHARMACEUTICALS',
#  'DUTCH OPHTHALMIC USA',
#  'DUX INDUSTRIES',
#  'DYAX',
#  'DYNASPLINT SYSTEMS',
#  'DYSIS MEDICAL',
#  'EBI MEDICAL SYSTEMS',
#  'ECARDIO DIAGNOSTICS',
#  'ECKERT ZIEGLER BEBIG',
#  'ECR PHARMACEUTICALS CO',
#  'EDGEMONT PHARMACEUTICALS',
#  'EDWARDS LIFESCIENCES',
#  'EGALET US',
#  'EISAI',
#  'EKOS',
#  'ELECTROMED',
#  'ELECTRONIC WAVEFORM LAB',
#  'ELEKTA',
#  'ELEKTA LIMITED',
#  'ELI LILLY AND COMPANY',
#  'ELLMAN INTERNATIONAL',
#  'EMD SERONO',
#  'EMERGENT BIOSOLUTIONS',
#  'EMPI',
#  'ENCORE DERMATOLOGY',
#  'ENCORE MEDICAL',
#  'ENDO PHARMACEUTICALS',
#  'ENDOCARE',
#  'ENDOCHOICE',
#  'ENDOCO DBA ULTIMATE DENTAL',
#  'ENDOGASTRIC SOLUTIONS',
#  'ENDOLOGIX',
#  'ENDOSHAPE',
#  'ENTELLUS MEDICAL',
#  'EPIMED INTERNATIONAL',
#  'ER SQUIBB SONS',
#  'ERBE USA',
#  'ERMI',
#  'ESSENTIAL DENTAL SYSTEMS',
#  'ETHICON',
#  'ETHICON ENDOSURGERY',
#  'ETHICON US',
#  'EXACTA DENTAL PRODUCTS',
#  'EXACTECH',
#  'EXELIXIS',
#  'EXELTIS USA',
#  'EXTREMITY MEDICAL',
#  'F HOFFMANNLA ROCHE AG',
#  'FERRING INTERNATIONAL CENTER SA',
#  'FERRING PHARMACEUTICALS',
#  'FIDIA PHARMA USA',
#  'FISHER PAYKEL HEALTHCARE',
#  'FISHER SCIENTIFIC COMPANY',
#  'FLOWONIX MEDICAL',
#  'FOREST PHARMACEUTICALS',
#  'FOREST RESEARCH INSTITUTE',
#  'FRESENIUS USA',
#  'FRESENIUS USA MARKETING',
#  'FSC LABORATORIES',
#  'FUJIFILM MEDICAL SYSTEMS USA',
#  'FUJIFILM SONOSITE',
#  'GAC INTERNATIONAL',
#  'GALDERMA LABORATORIES',
#  'GALEN US',
#  'GALENA BIOPHARMA',
#  'GAMBRO AAB',
#  'GAMMA MEDICA',
#  'GAUSS SURGICAL',
#  'GC AMERICA',
#  'GE HEALTHCARE',
#  'GEBAUER COMPANY',
#  'GEISTLICH PHARMA NORTH AMERICA',
#  'GEMINI LABORATORIES',
#  'GENENTECH',
#  'GENENTECH USA',
#  'GENZYME',
#  'GI SUPPLY',
#  'GILEAD SCIENCES',
#  'GIVEN IMAGING',
#  'GIVEN IMAGING LTD',
#  'GLAUKOS',
#  'GLAXOSMITHKLINE',
#  'GLOBUS MEDICAL',
#  'GREAT LAKES MEDICAL SERVICES',
#  'GREATBATCH',
#  'GREER LABORATORIES',
#  'GRIFOLS SHARED SERVICES',
#  'GRIFOLS USA',
#  'GUERBET',
#  'H LUNDBECK A S',
#  'HAEMONETICS',
#  'HALOZYME',
#  'HALT MEDICAL',
#  'HALYARD HEALTH',
#  'HANSEN MEDICAL',
#  'HARVEST TECHNOLOGIES',
#  'HEARTWARE',
#  'HEIDELBERG ENGINEERING',
#  'HENRY SCHEIN',
#  'HENRY SCHEIN PRACTICE SOLUTIONS',
#  'HERAEUS KULZER',
#  'HF ACQUISITION CO',
#  'HIOSSEN',
#  'HITACHI ALOKA MEDICAL AMERICA',
#  'HITACHI MEDICAL SYSTEMS AMERICA',
#  'HOFFMANNLA ROCHE LIMITED',
#  'HOLLISTER',
#  'HOLOGIC',
#  'HORIZON PHARMA PLC',
#  'HORIZON PHARMA RHEUMATOLOGY',
#  'HORIZON PHARMA USA',
#  'HOSPIRA WORLDWIDE',
#  'HOYA SURGICAL OPTICS',
#  'HUFRIEDY MFG CO',
#  'HYPERION THERAPEUTICS',
#  'HZNP USA',
#  'IBA MOLECULAR NORTH AMERICA',
#  'ICAD',
#  'ICONACY_ORTHOPEDIC_IMPLANTS_',
#  'IMPAX LABORATORIES',
#  'IMPEDIMED',
#  'IMPLANT DIRECT SYBRON INTERNATIONAL',
#  'INDIVIOR',
#  'INNOCUTIS HOLDINGS',
#  'INNOVASIS',
#  'INNOVATIVE CRYOSURGERY',
#  'INNOVATIVE LASERS',
#  'INNOVATIVE MEDICAL TECHNOLOGIES',
#  'INNOVATIVE OPHTHALMIC PRODUCTS',
#  'INO THERAPEUTICS',
#  'INOVA LABS',
#  'INSTRADENT USA',
#  'INSTRUMENTATION LABORATORY COMPANY',
#  'INSULET',
#  'INSYS THERAPEUTICS',
#  'INTEGRA LIFESCIENCES',
#  'INTEGRA LIFESCIENCES SALES',
#  'INTEGRA SALES',
#  'INTEGRATED DENTAL SYSTEMS',
#  'INTERMUNE',
#  'INTERSECT ENT',
#  'INTUITIVE SURGICAL',
#  'INTUITIVE SURGICAL OPERATIONS',
#  'IPSEN BIOPHARM LIMITED',
#  'IPSEN BIOPHARMACEUTICALS',
#  'IPSEN INNOVATION',
#  'IRHYTHM TECHNOLOGIES',
#  'IROKO PHARMACEUTICALS',
#  'IRONWOOD PHARMACEUTICALS',
#  'ISORAY',
#  'ISOTIS ORTHOBIOLIGICS',
#  'ISTO TECHNOLOGIES',
#  'IVOCLAR VIVADENT',
#  'J MORITA USA',
#  'JANSSEN BIOTECH',
#  'JANSSEN DIAGNOSTICS',
#  'JANSSEN GLOBAL SERVICES',
#  'JANSSEN PHARMACEUTICALS',
#  'JANSSEN PRODUCTS',
#  'JANSSEN RESEARCH DEVELOPMENT',
#  'JANSSEN SCIENTIFIC AFFAIRS',
#  'JAZZ PHARMACEUTICALS',
#  'JOHNSON AND JOHNSON INTERNATIONAL',
#  'JOHNSON JOHNSON HEALTH CARE SYSTEMS',
#  'JOHNSON JOHNSON VISION CARE',
#  'JUBILANT HOLLISTERSTIER',
#  'K2M',
#  'KADMON PHARMACEUTICALS',
#  'KAIROS SURGICAL',
#  'KALEO',
#  'KARLSTORZ ENDOSCOPYAMERICA',
#  'KCI USA',
#  'KEDRION BIOPHARMA',
#  'KENSEY NASH',
#  'KERR',
#  'KERYX BIOPHARMACEUTICALS',
#  'KEYSTONE DENTAL',
#  'KEYSTONE SURGICAL SYSTEMS',
#  'KLS MARTIN',
#  'KONAN MEDICAL USA',
#  'KOWA PHARMACEUTICALS AMERICA',
#  'KURARAY AMERICA',
#  'LABORIE MEDICAL TECHNOLOGIES',
#  'LANNETT COMPANY',
#  'LANTHEUS MEDICAL IMAGING',
#  'LANX',
#  'LASER SPECIALTY MEDICAL',
#  'LDR SPINE USA',
#  'LEMAITRE VASCULAR',
#  'LENSAR',
#  'LEO PHARMA',
#  'LEO PHARMA AS',
#  'LIBERTY SURGICAL',
#  'LIFE SPINE',
#  'LIFECELL',
#  'LIFENET HEALTH',
#  'LIFESCAN',
#  'LIFEWATCH SERVICES',
#  'LIGHTSCAEL',
#  'LILLY USA',
#  'LINEAGE THERAPEUTICS',
#  'LINVATEC',
#  'LIPOSCIENCE',
#  'LIVENTA BIOSCIENCES',
#  'LOMBARD MEDICAL TECHNOLOGIES',
#  'LSI SOLUTIONS',
#  'LUITPOLD PHARMACEUTICALS',
#  'LUMARA HEALTH',
#  'LUMENIS',
#  'LUMINEX',
#  'LUNDBECK',
#  'LUNG BIOTECHNOLOGY',
#  'LUPIN PHARMACEUTICALS',
#  'LUTONIX',
#  'MACULOGIX',
#  'MAKO SURGICAL',
#  'MALLKRODT',
#  'MAQUET CARDIOVASCULAR',
#  'MAQUET CARDIOVASCULAR US SALES',
#  'MARATHON PHARMACEUTICALS',
#  'MARCO OPHTHALMIC',
#  'MASIMO',
#  'MATERIALISE DENTAL',
#  'MATERIALISE USA',
#  'MAUNA KEA TECHNOLOGIES',
#  'MAXX ORTHOPEDICS',
#  'MAYNE PHARMA',
#  'MAZOR ROBOTICS',
#  'MCKESSON SPECIALTY CARE DISTRIBUTION',
#  'MEDA PHARMACEUTICALS',
#  'MEDAC PHARMA',
#  'MEDACTA USA',
#  'MEDAFOR',
#  'MEDARTIS',
#  'MEDEL',
#  'MEDELA',
#  'MEDERI THERAPEUTICS',
#  'MEDICOMP',
#  'MEDICREA USA',
#  'MEDIMETRIKS PHARMACEUTICALS',
#  'MEDIMMUNE',
#  'MEDIVANCE',
#  'MEDIVATION',
#  'MEDIVATORS',
#  'MEDLINE INDUSTRIES',
#  'MEDRAD',
#  'MEDTRONIC',
#  'MEDTRONIC MINIMED',
#  'MEDTRONIC NEUROVASCULAR',
#  'MEDTRONIC SOFAMOR DANEK USA',
#  'MEDTRONIC USA',
#  'MEDTRONIC VASCULAR',
#  'MEDTRONIC XOMED',
#  'MEISINGER USA',
#  'MELA SCIENCES',
#  'MENTOR WORLDWIDE',
#  'MERCATOR MEDSYSTEMS',
#  'MERCEDES MEDICAL',
#  'MERCK SHARP DOHME',
#  'MERGE HEALTHCARE',
#  'MERIDIAN BIOSCIENCE',
#  'MERIT MEDICAL SYSTEMS',
#  'MERZ',
#  'MERZ NORTH AMERICA',
#  'METREX RESEARCH',
#  'MICROAIRE SURGICAL INSTRUMENTS',
#  'MICROPORT ORTHOPEDICS',
#  'MICROVENTION',
#  'MIDATECH PHARMA US',
#  'MIDMARK',
#  'MILLENNIUM PHARMACEUTICALS',
#  'MILLIKEN HEALTHCARE PRODUCTS',
#  'MINDRAY DS USA',
#  'MIROMATRIX MEDICAL',
#  'MIS IMPLANTS TECHNOLOGIES',
#  'MISONIX',
#  'MISSION PHARMACAL COMPANY',
#  'MIST PHARMACEUTICALS',
#  'MOLNLYCKE HEALTH CARE US',
#  'MONTERIS MEDICAL',
#  'MRI INTERVENTIONS',
#  'MUSCULOSKELETAL TRANSPLANT FOUNDATION',
#  'MYDENT INTERNATIONAL',
#  'MYLAN PHARMACEUTICALS',
#  'MYLAN SPECIALTY',
#  'MYRIAD GENETIC LABORATORIES',
#  'NANOSPHERE',
#  'NANOSTRING TECHNOLOGIES',
#  'NATIONAL DENTEX',
#  'NAUTILUS NEUROSCIENCES',
#  'NCONTACT SURGICAL',
#  'NDI MEDICAL',
#  'NEOMEDIX',
#  'NEOMEND',
#  'NEOTRACT',
#  'NEURONETICS',
#  'NEUROPACE',
#  'NEUROTHERM',
#  'NEUWAVE MEDICAL',
#  'NEVRO',
#  'NEW STAR LASERS',
#  'NEW WAVE SURGICAL',
#  'NEW WORLD MEDICAL',
#  'NEXTREMITY SOLUTIONS',
#  'NICO',
#  'NINEPOINT MEDICAL',
#  'NOBEL BIOCARE USA',
#  'NONIN MEDICAL',
#  'NORGENIX PHARMACEUTICALS',
#  'NORTHEAST CRYOTHERAPY',
#  'NOVADAQ TECHNOLOGIES',
#  'NOVARTIS CONSUMER HEALTH',
#  'NOVARTIS PHARMA AG',
#  'NOVARTIS PHARMACEUTICALS',
#  'NOVARTIS VACCINES AND DIAGNOSTICS',
#  'NOVEN PHARMACEUTICALS',
#  'NOVEN THERAPEUTICS',
#  'NOVO NORDISK',
#  'NOVO NORDISK AS',
#  'NOVOCURE',
#  'NOVUM PHARMA',
#  'NPS PHARMACEUTICALS',
#  'NUVASIVE',
#  'NXSTAGE MEDICAL',
#  'OASIS MEDICAL',
#  'OCTAPHARMA USA',
#  'OCULAR THERAPEUTIX',
#  'OCULUS',
#  'OLYMPUS AMERICA',
#  'OLYMPUS BIOTECH',
#  'OLYMPUS OF THE AMERICAS',
#  'OMEROS',
#  'OMNIGUIDE',
#  'ONSET DERMATOLOLOGY',
#  'ONYX PHARMACEUTICALS AN AMGEN SUBSIDIARY',
#  'OPTIMEDICA',
#  'OPTIMER PHARMACEUTICALS',
#  'OPTOS',
#  'OPTOS PLC',
#  'OPTOVUE',
#  'OREXO US',
#  'ORGAN RECOVERY SYSTEMS',
#  'ORGANOGENESIS',
#  'ORIGIO',
#  'ORMCO',
#  'ORTHALIGN',
#  'ORTHO DEVELOPMENT',
#  'ORTHO ORGANIZERS',
#  'ORTHO SOLUTIONS',
#  'ORTHOFIX INTERNATIONAL NV',
#  'ORTHOPEDIATRICS',
#  'ORTHOSENSOR',
#  'OSIRIS THERAPEUTICS',
#  'OSSEON',
#  'OSTEOMED',
#  'OSTEOREADY',
#  'OTICON MEDICAL',
#  'OTSUKA AMERICA PHARMACEUTICAL',
#  'OTSUKA PHARMACEUTICAL CO LTD',
#  'OTSUKA PHARMACEUTICAL DEVELOPMENT COMMERCIALIZATION',
#  'OXFORD IMMUNOTEC',
#  'OZARK CRYOSURGERY',
#  'PACIRA PHARMACEUTICALS',
#  'PANORAMIC RENTAL',
#  'PAR PHARMACEUTICAL',
#  'PARADIGM SPINE',
#  'PARAGON 28',
#  'PATTERSON COMPANIES',
#  'PENUMBRA',
#  'PERNIX THERAPEUTICS HOLDINGS',
#  'PERRIGO COMPANY PLC',
#  'PETER BRASSELER HOLDINGS',
#  'PFIZER',
#  'PFIZER HONG KONG LIMITED',
#  'PFIZER INTERNATIONAL',
#  'PFIZER PHARMA GMBH',
#  'PFIZER PHARMACEUTICALS',
#  'PHADIA US',
#  'PHARMACYCLICS',
#  'PHARMACYCLICS AN ABBVIE COMPANY',
#  'PHILIPS ELECTRONICS NORTH AMERICA',
#  'PHOTOCURE',
#  'PIERRE FABRE PHARMACEUTICALS',
#  'PINNACLE BIOLOGICS',
#  'PIRAMAL IMAGING LIMITED',
#  'PLANMECA USA',
#  'PLASMA SURGICAL',
#  'PRECISION SPINE',
#  'PRECISION THERAPEUTICS',
#  'PREMIER DENTAL PRODUCTS COMPANY',
#  'PRODIGY SURGICAL DISTRIBUTION',
#  'PROMETHEUS LABORATORIES',
#  'PROMIUS PHARMA',
#  'PROSTRAKAN',
#  'PROVIDENCE MEDICAL TECHNOLOGY',
#  'PRUGEN PHARMACEUTICALS',
#  'PSS WORLD MEDICAL',
#  'PUDENT',
#  'PURDUE PHARMA',
#  'PURDUE TRANSDERMAL TECHNOLOGIES',
#  'PURELIFE',
#  'QIAGEN SCIENCES',
#  'QOL MEDICAL',
#  'QUEST MEDICAL',
#  'QUESTCOR PHARMACEUTICALS',
#  'RADIOMETER AMERICA',
#  'RAINTREE ESSIX',
#  'RANBAXY',
#  'RAPID PATHOGEN SCREENING',
#  'RAPTOR PHARMACEUTICALS',
#  'RAYSEARCH LABORATORIES AB PUBL',
#  'RECKITT BENCKISER',
#  'RECKITT BENCKISER PHARMACEUTICALS',
#  'REGENERON HEALTHCARE SOLUTIONS',
#  'REGENERON PHARMACEUTICALS',
#  'REICHERT',
#  'RENAISSANCE PHARMA',
#  'RESMED',
#  'RESPICARDIA',
#  'RESPIRATORY TECHNOLOGIES',
#  'RETROPHIN',
#  'RHODES PHARMACEUTICALS',
#  'RICHARD WOLF MEDICAL INSTRUMENTS',
#  'RICHARDALLAN SCIENTIFIC COMPANY',
#  'RIKCO INTERNATIONAL',
#  'ROANOKE AREA SURGICAL LASERS',
#  'ROCHE DIABETES CARE',
#  'ROCHE DIAGNOSTICS',
#  'ROCHE HEALTH SOLUTIONS',
#  'ROCHE PRODUCTS LIMITED',
#  'ROCHE TCRC',
#  'ROCHESTER MEDICAL',
#  'ROMARK LABORATORIES LC',
#  'ROTATION MEDICAL',
#  'RTI SURGICAL',
#  'SAFCO DENTAL SUPPLY CO',
#  'SAGENT PHARMACEUTICALS',
#  'SALIX PHARMACEUTICALS LTD',
#  'SALVIN DENTAL SPECIALTIES',
#  'SANDOZ',
#  'SANOFI PASTEUR',
#  'SANOFI US SERVICES',
#  'SANOFIAVENTIS US',
#  'SANTARUS',
#  'SAUFLON PHARMACEUTICALS',
#  'SCANLAN INTERNATIONAL',
#  'SCICAN',
#  'SEAPEARL',
#  'SEATTLE GENETICS',
#  'SEBELA PHARMACEUTICALS',
#  'SECOND SIGHT MEDICAL PRODUCTS',
#  'SENSUS HEALTHCARE',
#  'SENTYNL THERAPEUTICS',
#  'SEPTODONT',
#  'SEQIRUS USA',
#  'SHIONOGI',
#  'SHIRE NORTH AMERICAN GROUP',
#  'SHIRE US HOLDINGS',
#  'SHOFU DENTAL',
#  'SIBONE',
#  'SIEMENS HEARING INSTRUMENTS',
#  'SIEMENS MEDICAL SOLUTIONS USA',
#  'SIENTRA',
#  'SIGMATAU PHARMACEUTICALS',
#  'SILVERGATE PHARMACEUTICALS',
#  'SIRONA DENTAL SYSTEMS',
#  'SIRTEX MEDICAL',
#  'SKELETAL DYNAMICS',
#  'SMALL BONE INNOVATIONS',
#  'SMITH NEPHEW',
#  'SMITHS MEDICAL ASD',
#  'SOBI',
#  'SOLANA SURGICAL',
#  'SONACARE MEDICAL',
#  'SONOMA ORTHOPEDICS',
#  'SORIN CRM USA',
#  'SORIN GROUP USA',
#  'SPECTRUM PHARMACEUTICALS',
#  'SPINAL MODULATION',
#  'SPINE VIEW',
#  'SPINE WAVE',
#  'SPINEART USA',
#  'SPINEFRONTIER',
#  'SPINEGUARD',
#  'SPINEOLOGY',
#  'SPINESMITH HOLDINGS',
#  'SPIRACUR',
#  'SPIRATION',
#  'SS WHITE BURS',
#  'ST JUDE MEDICAL',
#  'STAAR SURGICAL COMPANY',
#  'STABILITY',
#  'STEREOTAXIS',
#  'STRATEGIC DENTISTRY',
#  'STRAUMANN USA',
#  'STRYKER',
#  'SUCAMPO PHARMA AMERICAS',
#  'SUNOVION PHARMACEUTICALS',
#  'SUNSHINE HEART',
#  'SUNSTAR AMERICAS',
#  'SUPERNUS PHARMACEUTICALS',
#  'SURGIQUEST',
#  'SYNAPTIVE MEDICAL',
#  'SYNERGETICS USA',
#  'SYNERGEYES',
#  'SYNTHES USA PRODUCTS',
#  'SYSMEX INOSTICS',
#  'SYSTAGENIX WOUND MANAGEMENT',
#  'TACTILE SYSTEMS TECHNOLOGY',
#  'TAKEDA PHARMACEUTICALS AMERICA',
#  'TAKEDA PHARMACEUTICALS INTERNATIONAL',
#  'TAKEDA PHARMACEUTICALS USA',
#  'TANDEM DIABETES CARE',
#  'TARO PHARMACEUTICALS USA',
#  'TEARLAB',
#  'TEI BIOSCIENCES',
#  'TEI MEDICAL',
#  'TELEFLEX MEDICAL',
#  'TEM SYSTEMS',
#  'TENEX HEALTH',
#  'TEPHA',
#  'TERUMO BCT',
#  'TERUMO CARDIOVASCULAR SYSTEMS',
#  'TERUMO MEDICAL',
#  'TEVA PHARMACEUTICALS USA',
#  'THE CAMERONEHLEN GROUP',
#  'THE MEDICINES COMPANY',
#  'THE SPECTRANETICS',
#  'THE WALMAN OPTICAL COMPANY',
#  'THERATECHNOLOGIES',
#  'THERAVANCE',
#  'THERRX',
#  'THORATEC',
#  'THROMBOGENICS',
#  'TISSUETECH',
#  'TITAN SPINE',
#  'TOKUYAMA DENTAL AMERICA',
#  'TOLMAR PHARMACEUTICALS',
#  'TOPCON',
#  'TOPCON MEDICAL SYSTEMS',
#  'TOPERA',
#  'TORAX MEDICAL',
#  'TORNIER',
#  'TOSHIBA AMERICA MEDICAL SYSTEMS',
#  'TOSOH BIOSCIENCE',
#  'TOTAL JOINT ORTHOPEDICS',
#  'TRILLIANT SURGICAL LTD',
#  'TRIREME MEDICAL',
#  'TRIVASCULAR',
#  'TULSA DENTAL PRODUCTS',
#  'TURING PHARMACEUTICALS',
#  'TYRX',
#  'UCB',
#  'UCB SA',
#  'UHS SURGICAL SERVICES',
#  'ULTRADENT PRODUCTS',
#  'UNITED THERAPEUTICS',
#  'UNIVERSAL MEDICAL',
#  'UPSHERSMITH LABORATORIES',
#  'UROLOGIX',
#  'UROPLASTY',
#  'US ENDOSCOPY',
#  'US IMPLANT SOLUTIONS',
#  'US WORLDMEDS',
#  'VALEANT PHARMACEUTICALS NORTH AMERICA',
#  'VALERITAS',
#  'VALIDUS PHARMACEUTICALS',
#  'VANDA PHARMACEUTICALS',
#  'VANSEN PHARMA',
#  'VAPOTHERM',
#  'VARIAN MEDICAL SYSTEMS',
#  'VASAMED',
#  'VASCULAR INSIGHTS',
#  'VASCULAR SOLUTIONS',
#  'VAXSERVE',
#  'VENITI',
#  'VENTANA MEDICAL SYSTEMS',
#  'VERAN MEDICAL TECHNOLOGIES',
#  'VERMILLION',
#  'VERTEX PHARMACEUTICALS',
#  'VERTICAL PHARMACEUTICALS',
#  'VERTOS MEDICAL',
#  'VIIV HEALTHCARE COMPANY',
#  'VIROPHARMA',
#  'VISIONARY OPTICS',
#  'VISIONCARE OPHTHALMIC TECHNOLOGIES',
#  'VISIONSCOPE TECHNOLOGIES',
#  'VISUALASE',
#  'VITAPHONE_USA_',
#  'VIVUS',
#  'VOCO AMERICA',
#  'VOLCANO',
#  'W L GORE ASSOCIATES',
#  'WARNER CHILCOTT',
#  'WELCH ALLYN',
#  'WENZEL SPINE',
#  'WOCKHARDT USA',
#  'WOUND CARE TECHNOLOGIES',
#  'WRIGHT MEDICAL TECHNOLOGY',
#  'WRIGHT THERAPY PRODUCTS',
#  'XENOPORT',
#  'XSPINE SYSTEMS',
#  'YOUNG DENTAL MANUFACTURING I',
#  'YOUNG PS ACQUISITIONS',
#  'YTE',
#  'ZIEHM IMAGING',
#  'ZIMMER BIOMET HOLDINGS',
#  'ZOGENIX',
#  'ZOLL CIRCULATION',
#  'ZOLL LIFECOR',
#  'ZOLL MEDICAL',
#  'ZYGA TECHNOLOGY']

# %%
len(np.intersect1d(sorted(scripts['drug_company'].unique()),sorted(x)))
# Out:
# 113

# %%
scripts.to_csv('/volumes/Seagate/Galvanize/nj_scripts_all_years.csv',index=False)

# %%
l = list(scripts[(scripts['drug_name']=='ALPRAZOLAM INTENSOL')&(scripts['generic_name']=='ALPRAZOLAM INTENSOL')].index.values)
for i in l:
    scripts.at[i,'drug_company'] = 'GENERIC'
